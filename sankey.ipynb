# %%
# !jupyter nbextension enable --py --sys-prefix ipysankeywidget
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension jupyter-sankey-widget/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
jupyter nbextension enable --py --sys-prefix ipysankeywidget
jupyter nbextension enable --py --sys-prefix widgetsnbextension

# %%
import random
import datetime
#from ipysankeywidget import SankeyWidget
#from ipywidgets import Layout

import ipysankeywidget as sk
import ipywidgets as ipw
import pandas as pd

# %%
# Generate sample data

locations = ['Produce', 'Dairy', 'Freezer', 'Chips', 'Cookies', 'Cereal', 'Produce', 'Dairy','Produce', 'Dairy','Cereal' ]

def generate_customers(num_custs=200):
    
    customer_list = []
    while len(customer_list) <= num_custs:
        customer_list.append('CUST-' + str(random.randrange(1,101)))
    print('Unique Customers = ', len(set(customer_list)))
    
    return customer_list

def generate_sample_data(sample_size=10000, num_custs=200):
    sample_data = []
    
    customers = generate_customers(num_custs)
    
    while len(sample_data) < sample_size:
        month = random.randrange(1,7)
        day = random.randrange(1,29)
        hour = random.randrange(8,22)
        
        rand_customer = customers[random.randrange(0,200)]
        
        for i in range(random.randrange(8)):

            minute = random.randrange(1,60)
            seconds = random.randrange(1,60)
            rand_location = locations[random.randrange(0,(len(locations)))]
            rand_timestamp = datetime.datetime(2019, month, day, hour, minute, seconds)

            item = {'timestamp':str(rand_timestamp), 'customer':rand_customer, 'location': rand_location}
            sample_data.append(item)

    print('Data Points Generated = ', len(sample_data))
    return sample_data

# %%
raw_data = generate_sample_data()
# Out:
# Unique Customers =  85
# Data Points Generated =  10000

# %%
df = pd.DataFrame(raw_data)
df['timestamp']= pd.to_datetime(df['timestamp'])
df.sort_values(['customer', 'timestamp'], inplace=True)
df.head(10)
# Out:
#                timestamp customer location
# 6488 2019-01-06 08:09:52   CUST-1    Dairy
# 6486 2019-01-06 08:10:19   CUST-1  Freezer
# 6487 2019-01-06 08:15:52   CUST-1    Dairy
# 2617 2019-01-06 12:15:23   CUST-1    Dairy
# 2618 2019-01-06 12:20:22   CUST-1  Produce
# 2616 2019-01-06 12:48:32   CUST-1  Produce
# 2619 2019-01-06 12:52:48   CUST-1  Freezer
# 1078 2019-01-25 13:34:26   CUST-1  Produce
# 1079 2019-01-25 13:38:44   CUST-1  Cookies
# 9171 2019-02-08 15:52:33   CUST-1  Freezer

# %%
accounts = list(df['customer'].unique())
area_types = list(df['location'].unique())

# tag the step number of each customer, regardless of visit
all_steps = [] # for total customer tracking over time

day_steps = [] # for daily trip tracking

next_steps = [] # for single area transversal
for account in accounts:
    row = {}
    row['account_num'] = account
    single_account = df[(df['customer'] == account)== True]
    
    steps = list(single_account['location']) 
    
    for count, locs in enumerate(steps, 1):
    
        row[str('col' + str(count))] = locs
        
        if count == 1:
            source = locs
            next
        
        
        next_steps.append({'source':source, 'target': locs+'1', 'value': 1})
        
        source = locs
        
    row['value'] = 1
    all_steps.append(row)
    
    

df_next = pd.DataFrame(next_steps)

# %%
# Everything Colors





def custom_colors(categories, opacity='100', exclude=None):


    num_cats = len(categories)

 
    cat_colors = ["1f77b4",
                  "ff7f0e", 
                  "2ca02c", 
                  "d62728", 
                  "9467bd", 
                  "8c564b", 
                  "e377c2", 
                  "7f7f7f", 
                  "bcbd22",
                  "17becf",
                 ]

    cat_colors = ['#' + color for color in cat_colors]


    full_color_map = dict(zip(categories[:num_cats], cat_colors[:num_cats]))

    if exclude in categories:
        full_color_map[exclude] = full_color_map[exclude].replace(str('#'+tranparency[opacity]), "#FF")
        

    return full_color_map

# %%
colormap = transparent(locations, opacity='100', exclude=None)

#df_next['color']=df_next['source'].apply(lambda x: colormap[x])
df_next.head(50)

next_grouped = df_next.groupby(['source','target']).sum().reset_index()

# %%
next_grouped['color']=next_grouped['source'].apply(lambda x: colormap[x])
links = next_grouped.to_dict(orient='records')

# %%
next_grouped
# Out:
#      source    target  value    color
# 0    Cereal   Cereal1    317  #8c564b
# 1    Cereal    Chips1    150  #8c564b
# 2    Cereal  Cookies1    174  #8c564b
# 3    Cereal    Dairy1    528  #8c564b
# 4    Cereal  Freezer1    167  #8c564b
# 5    Cereal  Produce1    469  #8c564b
# 6     Chips   Cereal1    174  #d62728
# 7     Chips    Chips1     78  #d62728
# 8     Chips  Cookies1     90  #d62728
# 9     Chips    Dairy1    244  #d62728
# 10    Chips  Freezer1     68  #d62728
# 11    Chips  Produce1    247  #d62728
# 12  Cookies   Cereal1    168  #9467bd
# 13  Cookies    Chips1     71  #9467bd
# 14  Cookies  Cookies1     88  #9467bd
# 15  Cookies    Dairy1    244  #9467bd
# 16  Cookies  Freezer1     80  #9467bd
# 17  Cookies  Produce1    247  #9467bd
# 18    Dairy   Cereal1    481  #17becf
# 19    Dairy    Chips1    255  #17becf
# 20    Dairy  Cookies1    235  #17becf
# 21    Dairy    Dairy1    746  #17becf
# 22    Dairy  Freezer1    279  #17becf
# 23    Dairy  Produce1    744  #17becf
# 24  Freezer   Cereal1    178  #2ca02c
# 25  Freezer    Chips1     82  #2ca02c
# 26  Freezer  Cookies1     83  #2ca02c
# 27  Freezer    Dairy1    257  #2ca02c
# 28  Freezer  Freezer1    100  #2ca02c
# 29  Freezer  Produce1    238  #2ca02c
# 30  Produce   Cereal1    497  #bcbd22
# 31  Produce    Chips1    266  #bcbd22
# 32  Produce  Cookies1    233  #bcbd22
# 33  Produce    Dairy1    719  #bcbd22
# 34  Produce  Freezer1    245  #bcbd22
# 35  Produce  Produce1    758  #bcbd22

# %%
layout = ipw.Layout(width="300", height="200")
def sankey(margin_top=10, **value):
    """Show SankeyWidget with default values for size and margins"""
    return sk.SankeyWidget(layout=layout,
                        margins=dict(top=margin_top, bottom=0, left=90, right=90),
                        **value)

# %%
'''links = [
    {'source': 'A', 'target': 'B', 'value': 1},
    {'source': 'B', 'target': 'C', 'value': 1},
    {'source': 'A', 'target': 'D', 'value': 1},
]'''
sankey(links=links)
# Out:
# SankeyWidget(layout=Layout(height='200', width='300'), links=[{'source': 'Cereal', 'target': 'Cereal1', 'value…

# %%
transparency = {"100":"FF",
                "99":"FC",
                "98":"FA",
                "97":"F7",
                "96":"F5",
                "95":"F2",
                "94":"F0",
                "93":"ED",
                "92":"EB",
                "91":"E8",
                "90":"E6",
                "89":"E3",
                "88":"E0",
                "87":"DE",
                "86":"DB",
                "85":"D9",
                "84":"D6",
                "83":"D4",
                "82":"D1",
                "81":"CF",
                "80":"CC",
                "79":"C9",
                "78":"C7",
                "77":"C4",
                "76":"C2",
                "75":"BF",
                "74":"BD",
                "73":"BA",
                "72":"B8",
                "71":"B5",
                "70":"B3",
                "69":"B0",
                "68":"AD",
                "67":"AB",
                "66":"A8",
                "65":"A6",
                "64":"A3",
                "63":"A1",
                "62":"9E",
                "61":"9C",
                "60":"99",
                "59":"96",
                "58":"94",
                "57":"91",
                "56":"8F",
                "55":"8C",
                "54":"8A",
                "53":"87",
                "52":"85",
                "51":"82",
                "50":"80",
                "49":"7D",
                "48":"7A",
                "47":"78",
                "46":"75",
                "45":"73",
                "44":"70",
                "43":"6E",
                "42":"6B",
                "41":"69",
                "40":"66",
                "39":"63",
                "38":"61",
                "37":"5E",
                "36":"5C",
                "35":"59",
                "34":"57",
                "33":"54",
                "32":"52",
                "31":"4F",
                "30":"4D",
                "29":"4A",
                "28":"47",
                "27":"45",
                "26":"42",
                "25":"40",
                "24":"3D",
                "23":"3B",
                "22":"38",
                "21":"36",
                "20":"33",
                "19":"30",
                "18":"2E",
                "17":"2B",
                "16":"29",
                "15":"26",
                "14":"24",
                "13":"21",
                "12":"1F",
                "11":"1C",
                "10":"1A",
                "9":"17",
                "8":"14",
                "7":"12",
                "6":"0F",
                "5":"0D",
                "4":"0A",
                "3":"08",
                "2":"05",
                "1":"03",
                "0":"00",
              }

# %%
raw_data
# Out:
# [{'timestamp': '2019-01-25 20:53:35',
#   'customer': 'CUST-3',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-25 20:41:12',
#   'customer': 'CUST-3',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-25 20:33:22',
#   'customer': 'CUST-3',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-03 12:30:59',
#   'customer': 'CUST-30',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-03 12:54:22',
#   'customer': 'CUST-30',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-03 12:41:46',
#   'customer': 'CUST-30',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-03 12:51:48',
#   'customer': 'CUST-30',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-22 09:17:33',
#   'customer': 'CUST-19',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-22 09:46:12',
#   'customer': 'CUST-19',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-22 09:52:57',
#   'customer': 'CUST-19',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-22 09:30:51',
#   'customer': 'CUST-19',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-27 11:54:36',
#   'customer': 'CUST-9',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-27 11:57:57',
#   'customer': 'CUST-9',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-27 11:12:47',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-12 18:36:08',
#   'customer': 'CUST-77',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-12 18:04:09',
#   'customer': 'CUST-77',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-12 18:46:16',
#   'customer': 'CUST-77',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-12 18:12:18',
#   'customer': 'CUST-77',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-12 18:43:44',
#   'customer': 'CUST-77',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-12 18:47:17',
#   'customer': 'CUST-77',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-12 18:04:50',
#   'customer': 'CUST-77',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-07 20:50:57',
#   'customer': 'CUST-92',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-07 20:41:01',
#   'customer': 'CUST-92',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-06 21:06:16',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-06 21:52:32',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-06 21:38:13',
#   'customer': 'CUST-71',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-06 21:15:29',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-06 21:36:03',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-06 21:15:40',
#   'customer': 'CUST-71',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-28 12:41:29',
#   'customer': 'CUST-5',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-28 12:39:27',
#   'customer': 'CUST-5',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-28 12:01:36',
#   'customer': 'CUST-5',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-28 12:44:58',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-28 12:51:07',
#   'customer': 'CUST-5',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-28 12:45:37',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-28 12:43:12',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-16 20:06:07',
#   'customer': 'CUST-42',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-16 20:55:36',
#   'customer': 'CUST-42',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-16 20:13:29',
#   'customer': 'CUST-42',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-16 20:51:23',
#   'customer': 'CUST-42',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-16 20:37:44',
#   'customer': 'CUST-42',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-16 20:07:30',
#   'customer': 'CUST-42',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-16 20:18:36',
#   'customer': 'CUST-42',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-28 15:27:41',
#   'customer': 'CUST-99',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-28 15:50:02',
#   'customer': 'CUST-99',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-28 15:25:02',
#   'customer': 'CUST-99',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-28 15:46:14',
#   'customer': 'CUST-99',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-28 15:14:19',
#   'customer': 'CUST-99',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-28 15:19:29',
#   'customer': 'CUST-99',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-10 18:51:06',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-10 18:17:22',
#   'customer': 'CUST-5',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-10 18:57:10',
#   'customer': 'CUST-5',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-10 18:31:40',
#   'customer': 'CUST-5',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-10 18:54:03',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-19 20:27:01',
#   'customer': 'CUST-26',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-19 20:45:34',
#   'customer': 'CUST-26',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-19 20:53:06',
#   'customer': 'CUST-26',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-19 20:55:47',
#   'customer': 'CUST-26',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-19 20:24:48',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-23 11:28:20',
#   'customer': 'CUST-24',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-23 11:58:26',
#   'customer': 'CUST-24',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-23 11:47:17',
#   'customer': 'CUST-24',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-23 11:02:10',
#   'customer': 'CUST-24',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-23 11:42:09',
#   'customer': 'CUST-24',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-23 11:01:26',
#   'customer': 'CUST-24',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-23 11:07:12',
#   'customer': 'CUST-24',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-24 12:23:32',
#   'customer': 'CUST-71',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-24 12:05:45',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-24 12:42:10',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-24 12:06:43',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-24 12:24:51',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-24 13:43:12',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-24 13:08:45',
#   'customer': 'CUST-5',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-24 13:31:32',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-24 13:38:40',
#   'customer': 'CUST-5',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-24 13:11:50',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-24 13:06:20',
#   'customer': 'CUST-5',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-24 13:26:48',
#   'customer': 'CUST-5',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-22 19:58:47',
#   'customer': 'CUST-43',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-22 19:41:47',
#   'customer': 'CUST-43',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-22 19:48:23',
#   'customer': 'CUST-43',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-22 19:44:57',
#   'customer': 'CUST-43',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-22 19:39:10',
#   'customer': 'CUST-43',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-22 19:05:47',
#   'customer': 'CUST-43',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-04 09:15:26',
#   'customer': 'CUST-67',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-04 09:27:18',
#   'customer': 'CUST-67',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-09 19:32:36',
#   'customer': 'CUST-29',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-09 19:50:53',
#   'customer': 'CUST-29',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-09 19:22:07',
#   'customer': 'CUST-29',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-09 19:35:52',
#   'customer': 'CUST-29',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-09 19:14:25',
#   'customer': 'CUST-29',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-09 19:33:18',
#   'customer': 'CUST-29',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-09 19:19:45',
#   'customer': 'CUST-29',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-10 14:30:52',
#   'customer': 'CUST-30',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-10 14:49:37',
#   'customer': 'CUST-30',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-10 14:49:48',
#   'customer': 'CUST-30',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-10 14:30:18',
#   'customer': 'CUST-30',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-03 16:37:44',
#   'customer': 'CUST-24',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-03 16:15:50',
#   'customer': 'CUST-24',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-03 16:17:24',
#   'customer': 'CUST-24',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-03 16:10:36',
#   'customer': 'CUST-24',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-03 16:19:14',
#   'customer': 'CUST-24',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-03 16:01:41',
#   'customer': 'CUST-24',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-03 16:01:27',
#   'customer': 'CUST-24',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-21 18:32:31',
#   'customer': 'CUST-30',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-15 16:40:46',
#   'customer': 'CUST-73',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-15 16:37:57',
#   'customer': 'CUST-73',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-15 16:35:46',
#   'customer': 'CUST-73',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-24 08:19:51',
#   'customer': 'CUST-34',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-24 08:51:43',
#   'customer': 'CUST-34',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-17 08:33:11',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-17 08:29:40',
#   'customer': 'CUST-90',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-17 08:43:19',
#   'customer': 'CUST-90',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-17 08:57:02',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-17 08:52:55',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-17 08:03:02',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-04 11:32:12',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-04 11:07:42',
#   'customer': 'CUST-90',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-04 11:37:45',
#   'customer': 'CUST-90',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-04 11:24:43',
#   'customer': 'CUST-90',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-04 11:50:03',
#   'customer': 'CUST-90',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-08 12:26:08',
#   'customer': 'CUST-36',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-09 13:20:06',
#   'customer': 'CUST-53',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-09 13:45:09',
#   'customer': 'CUST-53',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-09 13:12:21',
#   'customer': 'CUST-53',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-09 13:09:10',
#   'customer': 'CUST-53',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-12 20:43:16',
#   'customer': 'CUST-25',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-12 20:02:45',
#   'customer': 'CUST-25',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-12 20:20:35',
#   'customer': 'CUST-25',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-12 20:52:39',
#   'customer': 'CUST-25',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-12 20:30:42',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-12 20:50:34',
#   'customer': 'CUST-25',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-12 20:23:44',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-13 12:24:04',
#   'customer': 'CUST-9',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-13 12:24:16',
#   'customer': 'CUST-9',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-23 18:23:38',
#   'customer': 'CUST-6',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-23 18:44:04',
#   'customer': 'CUST-6',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-08 18:26:25',
#   'customer': 'CUST-40',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-08 18:48:55',
#   'customer': 'CUST-40',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-10 11:33:45',
#   'customer': 'CUST-48',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-10 11:08:03',
#   'customer': 'CUST-48',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-10 11:37:12',
#   'customer': 'CUST-48',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-10 11:18:52',
#   'customer': 'CUST-48',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-10 11:27:17',
#   'customer': 'CUST-48',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-10 11:16:30',
#   'customer': 'CUST-48',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-10 11:13:44',
#   'customer': 'CUST-48',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-22 15:38:07',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-22 15:18:29',
#   'customer': 'CUST-70',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-22 15:16:44',
#   'customer': 'CUST-70',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-22 15:56:13',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-22 15:38:59',
#   'customer': 'CUST-70',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-22 15:04:49',
#   'customer': 'CUST-70',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-22 15:57:52',
#   'customer': 'CUST-70',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-11 20:41:29',
#   'customer': 'CUST-49',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-11 20:23:25',
#   'customer': 'CUST-49',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-11 20:23:55',
#   'customer': 'CUST-49',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-11 20:40:09',
#   'customer': 'CUST-49',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-04 11:13:45',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-04 11:44:36',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-04 11:46:07',
#   'customer': 'CUST-9',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-04 11:09:30',
#   'customer': 'CUST-9',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-18 19:47:20',
#   'customer': 'CUST-73',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-18 19:37:04',
#   'customer': 'CUST-73',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-18 19:11:11',
#   'customer': 'CUST-73',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-18 19:35:08',
#   'customer': 'CUST-73',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-18 19:41:46',
#   'customer': 'CUST-73',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-27 19:07:49',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-27 19:54:36',
#   'customer': 'CUST-71',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-27 19:31:24',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-27 19:53:52',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-27 19:51:59',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-16 19:28:33',
#   'customer': 'CUST-5',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-16 15:39:43',
#   'customer': 'CUST-97',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-16 15:24:24',
#   'customer': 'CUST-97',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-16 15:21:36',
#   'customer': 'CUST-97',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-16 15:14:36',
#   'customer': 'CUST-97',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-16 15:43:35',
#   'customer': 'CUST-97',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-16 15:34:25',
#   'customer': 'CUST-97',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-28 17:09:08',
#   'customer': 'CUST-9',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-28 17:06:56',
#   'customer': 'CUST-9',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-26 14:59:29',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-26 14:34:03',
#   'customer': 'CUST-9',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-26 14:31:12',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-26 14:54:05',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-26 14:37:19',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-04 17:35:56',
#   'customer': 'CUST-97',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-04 17:43:07',
#   'customer': 'CUST-97',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-04 17:32:49',
#   'customer': 'CUST-97',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-04 17:44:56',
#   'customer': 'CUST-97',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-23 16:28:23',
#   'customer': 'CUST-9',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-08 21:13:19',
#   'customer': 'CUST-56',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-08 21:45:30',
#   'customer': 'CUST-56',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-08 21:13:28',
#   'customer': 'CUST-56',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-08 21:21:27',
#   'customer': 'CUST-56',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-15 11:40:36',
#   'customer': 'CUST-10',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-15 11:24:17',
#   'customer': 'CUST-10',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-15 11:14:56',
#   'customer': 'CUST-10',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-17 15:30:23',
#   'customer': 'CUST-7',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-17 15:41:47',
#   'customer': 'CUST-7',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-17 15:53:36',
#   'customer': 'CUST-7',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-17 15:29:59',
#   'customer': 'CUST-7',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-17 15:56:01',
#   'customer': 'CUST-7',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-17 15:10:05',
#   'customer': 'CUST-7',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-17 15:10:41',
#   'customer': 'CUST-7',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-02 10:46:11',
#   'customer': 'CUST-11',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-02 10:06:13',
#   'customer': 'CUST-11',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-02 10:38:10',
#   'customer': 'CUST-11',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-02 10:28:58',
#   'customer': 'CUST-11',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-16 21:56:20',
#   'customer': 'CUST-76',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-16 21:49:54',
#   'customer': 'CUST-76',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-08 17:34:41',
#   'customer': 'CUST-83',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-08 17:07:08',
#   'customer': 'CUST-83',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-08 17:46:54',
#   'customer': 'CUST-83',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-08 17:40:29',
#   'customer': 'CUST-83',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-08 17:10:55',
#   'customer': 'CUST-83',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-23 21:50:41',
#   'customer': 'CUST-71',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-23 21:31:01',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-23 21:02:49',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-08 21:07:07',
#   'customer': 'CUST-34',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-08 21:51:42',
#   'customer': 'CUST-34',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-08 21:56:14',
#   'customer': 'CUST-34',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-08 21:47:36',
#   'customer': 'CUST-34',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-08 21:27:50',
#   'customer': 'CUST-34',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-08 21:21:42',
#   'customer': 'CUST-34',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-23 16:50:02',
#   'customer': 'CUST-5',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-26 12:15:08',
#   'customer': 'CUST-97',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-26 12:57:53',
#   'customer': 'CUST-97',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-25 13:29:12',
#   'customer': 'CUST-3',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-25 13:49:37',
#   'customer': 'CUST-3',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-25 13:15:27',
#   'customer': 'CUST-3',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-25 13:26:48',
#   'customer': 'CUST-3',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-07 15:29:20',
#   'customer': 'CUST-18',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-07 15:36:06',
#   'customer': 'CUST-18',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-07 15:07:24',
#   'customer': 'CUST-18',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-03 13:36:26',
#   'customer': 'CUST-73',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-03 13:05:56',
#   'customer': 'CUST-73',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-03 13:53:13',
#   'customer': 'CUST-73',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-13 14:45:52',
#   'customer': 'CUST-12',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-13 14:49:27',
#   'customer': 'CUST-12',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-13 14:40:24',
#   'customer': 'CUST-12',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-13 14:42:42',
#   'customer': 'CUST-12',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-13 14:42:26',
#   'customer': 'CUST-12',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-13 14:19:05',
#   'customer': 'CUST-12',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-13 14:17:36',
#   'customer': 'CUST-12',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-20 12:23:54',
#   'customer': 'CUST-3',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-20 12:51:04',
#   'customer': 'CUST-3',
#   'location': 'Chips'},
#  {'timestamp': '2019-03-20 12:06:56',
#   'customer': 'CUST-3',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-20 12:13:58',
#   'customer': 'CUST-3',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-21 17:04:08',
#   'customer': 'CUST-34',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-21 17:29:56',
#   'customer': 'CUST-34',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-21 17:38:44',
#   'customer': 'CUST-34',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-21 17:38:33',
#   'customer': 'CUST-34',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-18 13:08:47',
#   'customer': 'CUST-56',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-18 13:37:41',
#   'customer': 'CUST-56',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-18 13:30:10',
#   'customer': 'CUST-56',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-18 13:50:23',
#   'customer': 'CUST-56',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-05 13:20:46',
#   'customer': 'CUST-53',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-05 13:05:52',
#   'customer': 'CUST-53',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-05 13:24:09',
#   'customer': 'CUST-53',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-05 13:12:45',
#   'customer': 'CUST-53',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-05 13:04:32',
#   'customer': 'CUST-53',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-05 13:51:08',
#   'customer': 'CUST-53',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-22 13:57:35',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-22 13:24:32',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-22 13:55:29',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-22 13:28:42',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-23 09:13:58',
#   'customer': 'CUST-37',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-13 08:38:55',
#   'customer': 'CUST-38',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-13 08:40:46',
#   'customer': 'CUST-38',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-11 12:20:56',
#   'customer': 'CUST-54',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-11 12:53:03',
#   'customer': 'CUST-54',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-11 12:14:42',
#   'customer': 'CUST-54',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-15 08:04:23',
#   'customer': 'CUST-5',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-15 08:32:04',
#   'customer': 'CUST-5',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-15 08:52:59',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-15 08:01:43',
#   'customer': 'CUST-5',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-15 08:57:54',
#   'customer': 'CUST-5',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-20 11:32:03',
#   'customer': 'CUST-12',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-20 11:42:07',
#   'customer': 'CUST-12',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-20 11:12:47',
#   'customer': 'CUST-12',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-20 11:28:05',
#   'customer': 'CUST-12',
#   'location': 'Chips'},
#  {'timestamp': '2019-03-13 09:53:03',
#   'customer': 'CUST-95',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-13 09:41:26',
#   'customer': 'CUST-95',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-13 09:32:13',
#   'customer': 'CUST-95',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-13 09:45:44',
#   'customer': 'CUST-95',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-13 09:22:19',
#   'customer': 'CUST-95',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-05 09:11:02',
#   'customer': 'CUST-94',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-05 09:43:19',
#   'customer': 'CUST-94',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-23 09:43:42',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-17 20:15:24',
#   'customer': 'CUST-92',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-07 16:03:09',
#   'customer': 'CUST-73',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-07 16:24:05',
#   'customer': 'CUST-73',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-07 16:11:38',
#   'customer': 'CUST-73',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-07 16:43:17',
#   'customer': 'CUST-73',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-21 21:41:10',
#   'customer': 'CUST-25',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-21 21:04:45',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-21 21:37:02',
#   'customer': 'CUST-25',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-21 21:58:09',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-10 19:52:21',
#   'customer': 'CUST-43',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-10 19:12:30',
#   'customer': 'CUST-43',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-07 20:44:39',
#   'customer': 'CUST-54',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-07 20:02:29',
#   'customer': 'CUST-54',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-07 20:01:41',
#   'customer': 'CUST-54',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-07 20:27:35',
#   'customer': 'CUST-54',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-07 20:23:39',
#   'customer': 'CUST-54',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-07 20:59:56',
#   'customer': 'CUST-54',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-07 20:11:16',
#   'customer': 'CUST-54',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-26 18:51:19',
#   'customer': 'CUST-55',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-26 18:57:44',
#   'customer': 'CUST-55',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-26 18:18:16',
#   'customer': 'CUST-55',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-26 18:46:59',
#   'customer': 'CUST-55',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-28 19:10:23',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-28 19:31:29',
#   'customer': 'CUST-90',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-28 19:31:28',
#   'customer': 'CUST-90',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-16 20:36:51',
#   'customer': 'CUST-70',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-16 20:27:26',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-16 20:10:59',
#   'customer': 'CUST-70',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-16 20:39:13',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-16 20:45:50',
#   'customer': 'CUST-70',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-16 20:36:15',
#   'customer': 'CUST-70',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-16 20:27:52',
#   'customer': 'CUST-70',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-24 09:10:21',
#   'customer': 'CUST-76',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-20 17:05:45',
#   'customer': 'CUST-17',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-20 17:27:26',
#   'customer': 'CUST-17',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-19 13:27:35',
#   'customer': 'CUST-24',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-19 13:05:33',
#   'customer': 'CUST-24',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-01 10:32:06',
#   'customer': 'CUST-14',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-01 10:15:11',
#   'customer': 'CUST-14',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-01 10:58:08',
#   'customer': 'CUST-14',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-01 10:41:37',
#   'customer': 'CUST-14',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-01 10:18:17',
#   'customer': 'CUST-14',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-01 10:27:25',
#   'customer': 'CUST-14',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-01 10:02:35',
#   'customer': 'CUST-14',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-14 10:39:47',
#   'customer': 'CUST-95',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-14 10:05:41',
#   'customer': 'CUST-95',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-14 10:53:42',
#   'customer': 'CUST-95',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-14 10:51:59',
#   'customer': 'CUST-95',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-14 10:17:17',
#   'customer': 'CUST-95',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-14 10:01:45',
#   'customer': 'CUST-95',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-22 09:10:27',
#   'customer': 'CUST-67',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-22 09:30:39',
#   'customer': 'CUST-67',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-07 14:36:20',
#   'customer': 'CUST-50',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-07 14:39:08',
#   'customer': 'CUST-50',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-15 15:26:32',
#   'customer': 'CUST-9',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-15 15:50:35',
#   'customer': 'CUST-9',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-15 15:33:07',
#   'customer': 'CUST-9',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-15 15:13:57',
#   'customer': 'CUST-9',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-26 12:23:18',
#   'customer': 'CUST-34',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-26 12:39:51',
#   'customer': 'CUST-34',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-26 12:01:10',
#   'customer': 'CUST-34',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-26 12:57:35',
#   'customer': 'CUST-34',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-26 12:26:43',
#   'customer': 'CUST-34',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-26 12:50:25',
#   'customer': 'CUST-34',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-27 21:02:36',
#   'customer': 'CUST-36',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-27 21:32:41',
#   'customer': 'CUST-36',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-27 21:42:26',
#   'customer': 'CUST-36',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-27 21:44:43',
#   'customer': 'CUST-36',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-10 17:45:32',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-10 17:25:22',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-10 17:22:05',
#   'customer': 'CUST-71',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-10 17:46:31',
#   'customer': 'CUST-71',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-18 12:39:07',
#   'customer': 'CUST-81',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-18 12:35:08',
#   'customer': 'CUST-81',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-18 12:07:18',
#   'customer': 'CUST-81',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-18 12:02:12',
#   'customer': 'CUST-81',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-18 12:34:02',
#   'customer': 'CUST-81',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-16 11:28:27',
#   'customer': 'CUST-63',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-16 11:58:22',
#   'customer': 'CUST-63',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-16 11:56:05',
#   'customer': 'CUST-63',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-16 11:55:14',
#   'customer': 'CUST-63',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-27 14:04:14',
#   'customer': 'CUST-85',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-27 14:34:08',
#   'customer': 'CUST-85',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-27 14:58:20',
#   'customer': 'CUST-85',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-27 14:18:44',
#   'customer': 'CUST-85',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-27 14:37:22',
#   'customer': 'CUST-85',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-27 14:36:40',
#   'customer': 'CUST-85',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-10 20:42:10',
#   'customer': 'CUST-19',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-11 13:35:46',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-11 13:55:22',
#   'customer': 'CUST-9',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-11 13:52:02',
#   'customer': 'CUST-9',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-11 13:23:38',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-11 13:47:54',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-11 13:21:27',
#   'customer': 'CUST-9',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-11 13:12:08',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-17 10:48:52',
#   'customer': 'CUST-8',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-17 10:22:02',
#   'customer': 'CUST-8',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-17 10:24:11',
#   'customer': 'CUST-8',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-22 19:43:39',
#   'customer': 'CUST-26',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-25 20:20:35',
#   'customer': 'CUST-40',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-25 20:33:20',
#   'customer': 'CUST-40',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-25 20:07:42',
#   'customer': 'CUST-40',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-25 20:18:07',
#   'customer': 'CUST-40',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-25 20:23:23',
#   'customer': 'CUST-40',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-25 20:48:11',
#   'customer': 'CUST-40',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-25 20:28:57',
#   'customer': 'CUST-40',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-17 19:40:38',
#   'customer': 'CUST-92',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-12 17:28:59',
#   'customer': 'CUST-49',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-12 17:58:41',
#   'customer': 'CUST-49',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-09 19:57:15',
#   'customer': 'CUST-20',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-09 19:52:23',
#   'customer': 'CUST-20',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-09 19:27:36',
#   'customer': 'CUST-20',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-09 19:15:16',
#   'customer': 'CUST-20',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-09 19:18:49',
#   'customer': 'CUST-20',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-09 19:09:28',
#   'customer': 'CUST-20',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-09 19:19:26',
#   'customer': 'CUST-20',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-26 15:32:43',
#   'customer': 'CUST-19',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-26 15:26:42',
#   'customer': 'CUST-19',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-26 15:03:46',
#   'customer': 'CUST-19',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-10 18:21:50',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-10 18:01:11',
#   'customer': 'CUST-70',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-10 18:41:48',
#   'customer': 'CUST-70',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-10 18:44:38',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-26 08:02:07',
#   'customer': 'CUST-39',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-26 08:37:12',
#   'customer': 'CUST-39',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-26 08:32:35',
#   'customer': 'CUST-39',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-26 08:38:44',
#   'customer': 'CUST-39',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-26 08:10:24',
#   'customer': 'CUST-39',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-26 08:05:13',
#   'customer': 'CUST-39',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-26 08:39:56',
#   'customer': 'CUST-39',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-09 16:29:30',
#   'customer': 'CUST-20',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-09 16:59:01',
#   'customer': 'CUST-20',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-09 16:30:59',
#   'customer': 'CUST-20',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-09 16:16:07',
#   'customer': 'CUST-20',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-27 12:53:30',
#   'customer': 'CUST-72',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-27 12:25:33',
#   'customer': 'CUST-72',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-27 12:14:07',
#   'customer': 'CUST-72',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-27 12:12:08',
#   'customer': 'CUST-72',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-27 12:54:55',
#   'customer': 'CUST-72',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-27 12:27:55',
#   'customer': 'CUST-72',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-27 12:43:56',
#   'customer': 'CUST-72',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-03 08:14:32',
#   'customer': 'CUST-95',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-03 08:58:15',
#   'customer': 'CUST-95',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-03 08:51:56',
#   'customer': 'CUST-95',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-03 08:31:26',
#   'customer': 'CUST-95',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-03 08:31:56',
#   'customer': 'CUST-95',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-03 08:07:07',
#   'customer': 'CUST-95',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-24 16:37:33',
#   'customer': 'CUST-97',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-24 16:52:13',
#   'customer': 'CUST-97',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-24 16:57:15',
#   'customer': 'CUST-97',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-24 16:46:20',
#   'customer': 'CUST-97',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-24 16:50:54',
#   'customer': 'CUST-97',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-14 10:07:02',
#   'customer': 'CUST-94',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-14 10:04:07',
#   'customer': 'CUST-94',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-26 16:10:40',
#   'customer': 'CUST-7',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-26 16:13:44',
#   'customer': 'CUST-7',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-26 16:25:25',
#   'customer': 'CUST-7',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-26 16:34:08',
#   'customer': 'CUST-7',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-26 16:20:33',
#   'customer': 'CUST-7',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-26 16:47:45',
#   'customer': 'CUST-7',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-14 19:59:38',
#   'customer': 'CUST-7',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-14 19:32:34',
#   'customer': 'CUST-7',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-15 16:28:07',
#   'customer': 'CUST-100',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-15 16:28:29',
#   'customer': 'CUST-100',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-15 16:39:18',
#   'customer': 'CUST-100',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-15 16:42:53',
#   'customer': 'CUST-100',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-15 16:55:29',
#   'customer': 'CUST-100',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-15 16:18:59',
#   'customer': 'CUST-100',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-15 16:44:02',
#   'customer': 'CUST-100',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-07 10:38:50',
#   'customer': 'CUST-13',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-07 10:15:47',
#   'customer': 'CUST-13',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-07 10:10:33',
#   'customer': 'CUST-13',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-07 10:25:04',
#   'customer': 'CUST-13',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-07 10:54:41',
#   'customer': 'CUST-13',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-07 10:54:20',
#   'customer': 'CUST-13',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-27 16:39:27',
#   'customer': 'CUST-9',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-27 16:33:48',
#   'customer': 'CUST-9',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-27 16:16:49',
#   'customer': 'CUST-9',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-18 13:08:01',
#   'customer': 'CUST-24',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-18 13:23:20',
#   'customer': 'CUST-24',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-18 13:03:31',
#   'customer': 'CUST-24',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-18 13:04:28',
#   'customer': 'CUST-24',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-28 12:36:08',
#   'customer': 'CUST-46',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-28 12:21:14',
#   'customer': 'CUST-46',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-28 12:30:59',
#   'customer': 'CUST-46',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-28 12:32:56',
#   'customer': 'CUST-46',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-28 12:13:03',
#   'customer': 'CUST-46',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-28 12:31:39',
#   'customer': 'CUST-46',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-19 19:29:30',
#   'customer': 'CUST-25',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-19 19:19:17',
#   'customer': 'CUST-25',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-19 19:11:28',
#   'customer': 'CUST-25',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-19 19:19:04',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-19 19:02:24',
#   'customer': 'CUST-25',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-11 11:49:52',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-11 13:13:36',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-11 13:43:03',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-11 13:20:04',
#   'customer': 'CUST-26',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-11 13:34:05',
#   'customer': 'CUST-26',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-11 13:29:01',
#   'customer': 'CUST-26',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-27 13:26:28',
#   'customer': 'CUST-77',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-27 13:23:40',
#   'customer': 'CUST-77',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-27 13:11:42',
#   'customer': 'CUST-77',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-06 15:54:13',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-06 15:38:53',
#   'customer': 'CUST-90',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-06 15:41:17',
#   'customer': 'CUST-90',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-06 15:34:47',
#   'customer': 'CUST-90',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-06 15:48:52',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-06 15:09:37',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-14 13:54:44',
#   'customer': 'CUST-56',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-14 13:27:20',
#   'customer': 'CUST-56',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-14 13:57:57',
#   'customer': 'CUST-56',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-14 13:16:41',
#   'customer': 'CUST-56',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-14 13:59:22',
#   'customer': 'CUST-56',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-14 13:45:23',
#   'customer': 'CUST-56',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-14 13:55:38',
#   'customer': 'CUST-81',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-14 13:13:07',
#   'customer': 'CUST-81',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-14 13:13:03',
#   'customer': 'CUST-81',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-14 13:52:21',
#   'customer': 'CUST-81',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-14 13:35:01',
#   'customer': 'CUST-81',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-14 13:05:43',
#   'customer': 'CUST-81',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-10 18:18:01',
#   'customer': 'CUST-52',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-10 18:01:17',
#   'customer': 'CUST-52',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-10 18:10:57',
#   'customer': 'CUST-52',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-19 11:16:19',
#   'customer': 'CUST-73',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-19 11:28:27',
#   'customer': 'CUST-73',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-19 11:40:14',
#   'customer': 'CUST-73',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-19 11:18:09',
#   'customer': 'CUST-73',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-19 11:10:59',
#   'customer': 'CUST-73',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-19 11:47:30',
#   'customer': 'CUST-73',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-21 10:58:54',
#   'customer': 'CUST-33',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-21 10:45:07',
#   'customer': 'CUST-33',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-21 10:09:06',
#   'customer': 'CUST-33',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-21 10:29:23',
#   'customer': 'CUST-33',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-22 17:50:30',
#   'customer': 'CUST-36',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-22 17:31:53',
#   'customer': 'CUST-36',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-22 17:25:20',
#   'customer': 'CUST-36',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-22 17:15:35',
#   'customer': 'CUST-36',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-22 17:24:45',
#   'customer': 'CUST-36',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-22 17:40:06',
#   'customer': 'CUST-36',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-21 15:34:39',
#   'customer': 'CUST-18',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-21 15:52:11',
#   'customer': 'CUST-18',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-18 09:45:46',
#   'customer': 'CUST-74',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-18 09:01:50',
#   'customer': 'CUST-74',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-18 09:28:09',
#   'customer': 'CUST-74',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-18 09:48:55',
#   'customer': 'CUST-74',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-18 09:05:22',
#   'customer': 'CUST-74',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-18 09:01:43',
#   'customer': 'CUST-74',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-18 09:41:32',
#   'customer': 'CUST-74',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-04 15:08:36',
#   'customer': 'CUST-88',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-20 15:26:07',
#   'customer': 'CUST-34',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-07 20:04:43',
#   'customer': 'CUST-9',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-07 20:29:29',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-07 20:16:22',
#   'customer': 'CUST-9',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-07 20:36:50',
#   'customer': 'CUST-9',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-07 20:24:05',
#   'customer': 'CUST-9',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-14 14:21:37',
#   'customer': 'CUST-99',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-04 12:18:56',
#   'customer': 'CUST-31',
# ...
#   'customer': 'CUST-56',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-15 20:36:16',
#   'customer': 'CUST-56',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-12 14:19:25',
#   'customer': 'CUST-46',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-12 14:49:55',
#   'customer': 'CUST-46',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-12 14:07:09',
#   'customer': 'CUST-46',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-12 14:46:45',
#   'customer': 'CUST-46',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-12 14:02:13',
#   'customer': 'CUST-46',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-04 08:20:04',
#   'customer': 'CUST-37',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-04 08:22:49',
#   'customer': 'CUST-37',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-04 08:25:09',
#   'customer': 'CUST-37',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-04 08:09:46',
#   'customer': 'CUST-37',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-08 08:15:26',
#   'customer': 'CUST-34',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-08 08:40:23',
#   'customer': 'CUST-34',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-08 08:03:29',
#   'customer': 'CUST-34',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-18 16:07:53',
#   'customer': 'CUST-35',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-18 16:20:23',
#   'customer': 'CUST-35',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-18 16:40:58',
#   'customer': 'CUST-35',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-18 16:20:30',
#   'customer': 'CUST-35',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-18 16:41:55',
#   'customer': 'CUST-35',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-18 16:28:59',
#   'customer': 'CUST-35',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-18 16:06:29',
#   'customer': 'CUST-35',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-24 20:05:41',
#   'customer': 'CUST-92',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-02 13:12:18',
#   'customer': 'CUST-99',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-02 13:44:32',
#   'customer': 'CUST-99',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-02 13:02:57',
#   'customer': 'CUST-99',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-02 13:25:35',
#   'customer': 'CUST-99',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-14 14:25:15',
#   'customer': 'CUST-71',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-14 14:25:34',
#   'customer': 'CUST-71',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-14 14:17:39',
#   'customer': 'CUST-71',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-14 14:23:41',
#   'customer': 'CUST-71',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-14 14:45:45',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-14 14:25:02',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-14 14:39:30',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-15 16:31:33',
#   'customer': 'CUST-89',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-15 16:39:38',
#   'customer': 'CUST-89',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-05 20:49:12',
#   'customer': 'CUST-100',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-05 20:29:07',
#   'customer': 'CUST-100',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-05 20:48:19',
#   'customer': 'CUST-100',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-05 20:24:16',
#   'customer': 'CUST-100',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-05 20:43:25',
#   'customer': 'CUST-100',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-19 17:31:56',
#   'customer': 'CUST-90',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-19 17:36:28',
#   'customer': 'CUST-90',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-01 20:16:51',
#   'customer': 'CUST-14',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-01 20:35:31',
#   'customer': 'CUST-14',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-01 20:17:04',
#   'customer': 'CUST-14',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-01 20:06:32',
#   'customer': 'CUST-14',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-06 17:10:45',
#   'customer': 'CUST-18',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-06 17:40:10',
#   'customer': 'CUST-18',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-06 17:36:35',
#   'customer': 'CUST-18',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-06 17:18:03',
#   'customer': 'CUST-18',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-06 17:05:44',
#   'customer': 'CUST-18',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-06 17:58:06',
#   'customer': 'CUST-18',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-11 14:31:03',
#   'customer': 'CUST-90',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-11 14:02:45',
#   'customer': 'CUST-90',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-11 14:23:11',
#   'customer': 'CUST-90',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-11 14:06:53',
#   'customer': 'CUST-90',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-11 14:26:37',
#   'customer': 'CUST-90',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-11 14:33:47',
#   'customer': 'CUST-90',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-11 14:22:14',
#   'customer': 'CUST-90',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-03 20:36:57',
#   'customer': 'CUST-97',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-03 20:22:37',
#   'customer': 'CUST-97',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-03 20:17:41',
#   'customer': 'CUST-97',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-14 19:14:18',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-14 19:55:37',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-14 19:13:25',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-14 10:56:51',
#   'customer': 'CUST-49',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-14 10:26:45',
#   'customer': 'CUST-49',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-07 20:33:06',
#   'customer': 'CUST-45',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-07 20:11:08',
#   'customer': 'CUST-45',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-07 20:44:43',
#   'customer': 'CUST-45',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-07 20:11:45',
#   'customer': 'CUST-45',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-07 20:32:21',
#   'customer': 'CUST-45',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-22 20:56:21',
#   'customer': 'CUST-35',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-22 20:04:52',
#   'customer': 'CUST-35',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-21 15:22:45',
#   'customer': 'CUST-74',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-12 17:46:37',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-13 19:20:58',
#   'customer': 'CUST-58',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-13 19:38:09',
#   'customer': 'CUST-58',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-13 19:08:12',
#   'customer': 'CUST-58',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-04 08:56:31',
#   'customer': 'CUST-97',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-04 08:39:29',
#   'customer': 'CUST-97',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-13 15:27:33',
#   'customer': 'CUST-43',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-13 15:55:30',
#   'customer': 'CUST-43',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-13 15:50:18',
#   'customer': 'CUST-43',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-13 15:04:41',
#   'customer': 'CUST-43',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-13 15:31:53',
#   'customer': 'CUST-43',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-13 15:07:31',
#   'customer': 'CUST-43',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-13 15:07:19',
#   'customer': 'CUST-43',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-20 16:20:42',
#   'customer': 'CUST-24',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-20 16:24:57',
#   'customer': 'CUST-24',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-15 10:51:29',
#   'customer': 'CUST-5',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-28 18:36:45',
#   'customer': 'CUST-68',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-28 18:39:13',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-28 18:52:21',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-03 12:07:48',
#   'customer': 'CUST-74',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-03 12:47:20',
#   'customer': 'CUST-74',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-11 16:28:36',
#   'customer': 'CUST-92',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-11 16:25:29',
#   'customer': 'CUST-92',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-11 16:38:16',
#   'customer': 'CUST-92',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-11 16:54:41',
#   'customer': 'CUST-92',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-11 16:29:18',
#   'customer': 'CUST-92',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-11 16:20:32',
#   'customer': 'CUST-92',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-11 16:25:09',
#   'customer': 'CUST-92',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-14 18:25:40',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-14 18:08:50',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-14 18:09:17',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-14 18:48:15',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-25 16:18:38',
#   'customer': 'CUST-77',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-25 16:12:02',
#   'customer': 'CUST-77',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-25 16:08:34',
#   'customer': 'CUST-77',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-14 09:07:25',
#   'customer': 'CUST-42',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-14 09:36:46',
#   'customer': 'CUST-42',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-14 09:18:59',
#   'customer': 'CUST-42',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-28 08:49:53',
#   'customer': 'CUST-4',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-28 08:24:21',
#   'customer': 'CUST-4',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-28 08:04:44',
#   'customer': 'CUST-4',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-28 08:25:56',
#   'customer': 'CUST-4',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-28 08:17:11',
#   'customer': 'CUST-4',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-08 21:39:26',
#   'customer': 'CUST-5',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-08 21:16:17',
#   'customer': 'CUST-5',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-08 21:42:32',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-08 21:47:53',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-08 21:12:39',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-25 14:42:57',
#   'customer': 'CUST-57',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-25 14:58:10',
#   'customer': 'CUST-57',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-25 14:49:29',
#   'customer': 'CUST-57',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-25 14:33:23',
#   'customer': 'CUST-57',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-25 14:15:55',
#   'customer': 'CUST-57',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-25 14:09:05',
#   'customer': 'CUST-57',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-25 14:21:47',
#   'customer': 'CUST-57',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-12 20:32:47',
#   'customer': 'CUST-33',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-12 20:09:16',
#   'customer': 'CUST-33',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-12 20:22:26',
#   'customer': 'CUST-33',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-18 19:33:12',
#   'customer': 'CUST-75',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-18 19:46:17',
#   'customer': 'CUST-75',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-18 19:02:37',
#   'customer': 'CUST-75',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-18 19:48:48',
#   'customer': 'CUST-75',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-18 19:31:09',
#   'customer': 'CUST-75',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-18 19:10:46',
#   'customer': 'CUST-75',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-18 19:55:09',
#   'customer': 'CUST-75',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-21 21:38:38',
#   'customer': 'CUST-32',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-05 13:16:26',
#   'customer': 'CUST-67',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-05 13:38:10',
#   'customer': 'CUST-67',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-05 13:19:30',
#   'customer': 'CUST-67',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-05 13:57:19',
#   'customer': 'CUST-67',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-05 13:54:22',
#   'customer': 'CUST-67',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-05 13:57:31',
#   'customer': 'CUST-67',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-05 13:28:11',
#   'customer': 'CUST-67',
#   'location': 'Chips'},
#  {'timestamp': '2019-03-18 12:18:57',
#   'customer': 'CUST-75',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-18 12:09:31',
#   'customer': 'CUST-75',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-18 12:45:08',
#   'customer': 'CUST-75',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-04 21:30:51',
#   'customer': 'CUST-37',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-04 21:52:48',
#   'customer': 'CUST-37',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-04 21:39:23',
#   'customer': 'CUST-37',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-04 21:37:49',
#   'customer': 'CUST-37',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-04 21:56:26',
#   'customer': 'CUST-37',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-04 21:56:07',
#   'customer': 'CUST-37',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-22 12:09:38',
#   'customer': 'CUST-30',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-22 12:27:01',
#   'customer': 'CUST-30',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-22 12:57:53',
#   'customer': 'CUST-30',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-11 15:19:46',
#   'customer': 'CUST-30',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-21 14:08:26',
#   'customer': 'CUST-12',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-28 20:34:28',
#   'customer': 'CUST-73',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-28 20:51:22',
#   'customer': 'CUST-73',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-28 20:15:07',
#   'customer': 'CUST-73',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-28 20:19:41',
#   'customer': 'CUST-73',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-28 20:31:45',
#   'customer': 'CUST-73',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-11 19:44:17',
#   'customer': 'CUST-25',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-11 19:19:06',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-11 19:29:28',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-11 16:54:43',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-11 16:18:23',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-11 16:33:56',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-11 16:28:49',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-11 16:54:10',
#   'customer': 'CUST-25',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-11 16:50:45',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-11 16:33:12',
#   'customer': 'CUST-25',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-16 17:30:10',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-16 17:45:10',
#   'customer': 'CUST-5',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-16 17:48:45',
#   'customer': 'CUST-5',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-16 17:56:47',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-16 17:44:29',
#   'customer': 'CUST-5',
#   'location': 'Dairy'},
#  ...]
