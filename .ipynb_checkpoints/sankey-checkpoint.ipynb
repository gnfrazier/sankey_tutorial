# %%
# !jupyter nbextension enable --py --sys-prefix ipysankeywidget
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension jupyter-sankey-widget/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
import random
import datetime
#from ipysankeywidget import SankeyWidget
#from ipywidgets import Layout

import ipysankeywidget as sk
import ipywidgets as ipw
import pandas as pd

# %%
# Generate sample data

locations = ['Produce', 'Dairy', 'Freezer', 'Chips', 'Cookies', 'Cereal', 'Produce', 'Dairy','Produce', 'Dairy','Cereal' ]

def generate_customers(num_custs=200):
    
    customer_list = []
    while len(customer_list) <= num_custs:
        customer_list.append('CUST-' + str(random.randrange(1,101)))
    print('Unique Customers = ', len(set(customer_list)))
    
    return customer_list

def generate_sample_data(sample_size=10000, num_custs=200):
    sample_data = []
    
    customers = generate_customers(num_custs)
    
    while len(sample_data) < sample_size:
        month = random.randrange(1,7)
        day = random.randrange(1,29)
        hour = random.randrange(8,22)
        
        rand_customer = customers[random.randrange(0,200)]
        
        for i in range(random.randrange(8)):

            minute = random.randrange(1,60)
            seconds = random.randrange(1,60)
            rand_location = locations[random.randrange(0,(len(locations)))]
            rand_timestamp = datetime.datetime(2019, month, day, hour, minute, seconds)

            item = {'timestamp':str(rand_timestamp), 'customer':rand_customer, 'location': rand_location}
            sample_data.append(item)

    print('Data Points Generated = ', len(sample_data))
    return sample_data

# %%
raw_data = generate_sample_data()
# Out:
# Unique Customers =  82
# Data Points Generated =  10006

# %%
df = pd.DataFrame(raw_data)
df['timestamp']= pd.to_datetime(df['timestamp'])
df.sort_values(['customer', 'timestamp'], inplace=True)
df.head(10)
# Out:
#                timestamp  customer location
# 9045 2019-01-03 09:06:02  CUST-100   Cereal
# 9046 2019-01-03 09:50:44  CUST-100  Produce
# 5300 2019-01-03 18:19:37  CUST-100  Freezer
# 5301 2019-01-03 18:34:57  CUST-100  Produce
# 648  2019-01-06 18:06:35  CUST-100  Cookies
# 652  2019-01-06 18:19:30  CUST-100   Cereal
# 646  2019-01-06 18:20:05  CUST-100    Chips
# 651  2019-01-06 18:23:25  CUST-100  Freezer
# 647  2019-01-06 18:42:59  CUST-100    Dairy
# 649  2019-01-06 18:48:19  CUST-100    Dairy

# %%
accounts = list(df['customer'].unique())
area_types = list(df['location'].unique())

# tag the step number of each customer, regardless of visit
all_steps = [] # for total customer tracking over time

day_steps = [] # for daily trip tracking

next_steps = [] # for single area transversal
for account in accounts:
    row = {}
    row['account_num'] = account
    single_account = df[(df['customer'] == account)== True]
    
    steps = list(single_account['location']) 
    
    for count, locs in enumerate(steps, 1):
    
        row[str('col' + str(count))] = locs
        
        if count == 1:
            source = locs
            next
        
        
        next_steps.append({'source':source, 'target': locs+'1', 'value': 1})
        
        source = locs
        
    row['value'] = 1
    all_steps.append(row)
    
    

df_next = pd.DataFrame(next_steps)

# %%
# Everything Colors
tranparency = {"100":"FF",
                "99":"FC",
                "98":"FA",
                "97":"F7",
                "96":"F5",
                "95":"F2",
                "94":"F0",
                "93":"ED",
                "92":"EB",
                "91":"E8",
                "90":"E6",
                "89":"E3",
                "88":"E0",
                "87":"DE",
                "86":"DB",
                "85":"D9",
                "84":"D6",
                "83":"D4",
                "82":"D1",
                "81":"CF",
                "80":"CC",
                "79":"C9",
                "78":"C7",
                "77":"C4",
                "76":"C2",
                "75":"BF",
                "74":"BD",
                "73":"BA",
                "72":"B8",
                "71":"B5",
                "70":"B3",
                "69":"B0",
                "68":"AD",
                "67":"AB",
                "66":"A8",
                "65":"A6",
                "64":"A3",
                "63":"A1",
                "62":"9E",
                "61":"9C",
                "60":"99",
                "59":"96",
                "58":"94",
                "57":"91",
                "56":"8F",
                "55":"8C",
                "54":"8A",
                "53":"87",
                "52":"85",
                "51":"82",
                "50":"80",
                "49":"7D",
                "48":"7A",
                "47":"78",
                "46":"75",
                "45":"73",
                "44":"70",
                "43":"6E",
                "42":"6B",
                "41":"69",
                "40":"66",
                "39":"63",
                "38":"61",
                "37":"5E",
                "36":"5C",
                "35":"59",
                "34":"57",
                "33":"54",
                "32":"52",
                "31":"4F",
                "30":"4D",
                "29":"4A",
                "28":"47",
                "27":"45",
                "26":"42",
                "25":"40",
                "24":"3D",
                "23":"3B",
                "22":"38",
                "21":"36",
                "20":"33",
                "19":"30",
                "18":"2E",
                "17":"2B",
                "16":"29",
                "15":"26",
                "14":"24",
                "13":"21",
                "12":"1F",
                "11":"1C",
                "10":"1A",
                "9":"17",
                "8":"14",
                "7":"12",
                "6":"0F",
                "5":"0D",
                "4":"0A",
                "3":"08",
                "2":"05",
                "1":"03",
                "0":"00",
              }




def transparent(categories, opacity='100', exclude=None):


    num_cats = len(categories)

 
    cat_colors = ["1f77b4",
                  "ff7f0e", 
                  "2ca02c", 
                  "d62728", 
                  "9467bd", 
                  "8c564b", 
                  "e377c2", 
                  "7f7f7f", 
                  "bcbd22",
                  "17becf",
                 ]

    cat_colors = ['#' + tranparency[opacity] + color for color in cat_colors]


    full_color_map = dict(zip(categories[:num_cats], cat_colors[:num_cats]))

    if exclude in categories:
        full_color_map[exclude] = full_color_map[exclude].replace(str('#'+tranparency[opacity]), "#FF")
        

    return full_color_map

# %%
colormap = transparent(locations, opacity='100', exclude=None)

#df_next['color']=df_next['source'].apply(lambda x: colormap[x])
df_next.head(50)

next_grouped = df_next.groupby(['source','target']).sum().reset_index()

# %%
next_grouped['color']=next_grouped['source'].apply(lambda x: colormap[x])
links = next_grouped.to_dict(orient='records')

# %%
next_grouped
# Out:
#      source    target  value      color
# 0    Cereal   Cereal1    343  #FF8c564b
# 1    Cereal    Chips1    185  #FF8c564b
# 2    Cereal  Cookies1    157  #FF8c564b
# 3    Cereal    Dairy1    503  #FF8c564b
# 4    Cereal  Freezer1    177  #FF8c564b
# 5    Cereal  Produce1    462  #FF8c564b
# 6     Chips   Cereal1    179  #FFd62728
# 7     Chips    Chips1     82  #FFd62728
# 8     Chips  Cookies1     81  #FFd62728
# 9     Chips    Dairy1    239  #FFd62728
# 10    Chips  Freezer1     85  #FFd62728
# 11    Chips  Produce1    247  #FFd62728
# 12  Cookies   Cereal1    157  #FF9467bd
# 13  Cookies    Chips1     90  #FF9467bd
# 14  Cookies  Cookies1     81  #FF9467bd
# 15  Cookies    Dairy1    246  #FF9467bd
# 16  Cookies  Freezer1     78  #FF9467bd
# 17  Cookies  Produce1    282  #FF9467bd
# 18    Dairy   Cereal1    468  #FF17becf
# 19    Dairy    Chips1    239  #FF17becf
# 20    Dairy  Cookies1    255  #FF17becf
# 21    Dairy    Dairy1    772  #FF17becf
# 22    Dairy  Freezer1    269  #FF17becf
# 23    Dairy  Produce1    709  #FF17becf
# 24  Freezer   Cereal1    155  #FF2ca02c
# 25  Freezer    Chips1     89  #FF2ca02c
# 26  Freezer  Cookies1     81  #FF2ca02c
# 27  Freezer    Dairy1    255  #FF2ca02c
# 28  Freezer  Freezer1     82  #FF2ca02c
# 29  Freezer  Produce1    253  #FF2ca02c
# 30  Produce   Cereal1    533  #FFbcbd22
# 31  Produce    Chips1    233  #FFbcbd22
# 32  Produce  Cookies1    275  #FFbcbd22
# 33  Produce    Dairy1    688  #FFbcbd22
# 34  Produce  Freezer1    221  #FFbcbd22
# 35  Produce  Produce1    755  #FFbcbd22

# %%
layout = ipw.Layout(width="300", height="200")
def sankey(margin_top=10, **value):
    """Show SankeyWidget with default values for size and margins"""
    return sk.SankeyWidget(layout=layout,
                        margins=dict(top=margin_top, bottom=0, left=30, right=60),
                        **value)

# %%
'''links = [
    {'source': 'A', 'target': 'B', 'value': 1},
    {'source': 'B', 'target': 'C', 'value': 1},
    {'source': 'A', 'target': 'D', 'value': 1},
]'''
sankey(links=links)
# Out:
# SankeyWidget(layout=Layout(height='200', width='300'), links=[{'source': 'Cereal', 'target': 'Cereal1', 'value…

# %%
raw_data
# Out:
# [{'timestamp': '2019-02-09 13:58:10',
#   'customer': 'CUST-99',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-07 15:06:35',
#   'customer': 'CUST-86',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-07 15:30:06',
#   'customer': 'CUST-86',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-07 15:43:39',
#   'customer': 'CUST-86',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-07 15:48:24',
#   'customer': 'CUST-86',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-07 15:36:59',
#   'customer': 'CUST-86',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-07 15:54:24',
#   'customer': 'CUST-86',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-07 15:39:58',
#   'customer': 'CUST-86',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-08 12:49:14',
#   'customer': 'CUST-4',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-08 12:31:06',
#   'customer': 'CUST-4',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-08 12:45:28',
#   'customer': 'CUST-4',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-08 12:39:04',
#   'customer': 'CUST-4',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-04 18:53:43',
#   'customer': 'CUST-59',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-21 13:41:59',
#   'customer': 'CUST-67',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-21 13:18:24',
#   'customer': 'CUST-67',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-21 13:20:10',
#   'customer': 'CUST-67',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-21 13:03:04',
#   'customer': 'CUST-67',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-05 14:58:10',
#   'customer': 'CUST-15',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-05 14:11:22',
#   'customer': 'CUST-15',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-05 14:41:26',
#   'customer': 'CUST-15',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-05 14:14:44',
#   'customer': 'CUST-15',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-05 14:48:32',
#   'customer': 'CUST-15',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-24 18:15:47',
#   'customer': 'CUST-51',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-24 18:37:04',
#   'customer': 'CUST-51',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-24 18:43:02',
#   'customer': 'CUST-51',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-24 18:38:07',
#   'customer': 'CUST-51',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-24 18:49:08',
#   'customer': 'CUST-51',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-24 18:34:53',
#   'customer': 'CUST-51',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-24 18:17:43',
#   'customer': 'CUST-51',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-26 12:51:53',
#   'customer': 'CUST-76',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-26 12:58:29',
#   'customer': 'CUST-76',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-26 12:38:33',
#   'customer': 'CUST-76',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-26 12:58:19',
#   'customer': 'CUST-76',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-26 12:12:25',
#   'customer': 'CUST-76',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-26 12:53:28',
#   'customer': 'CUST-76',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-07 19:53:06',
#   'customer': 'CUST-29',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-07 19:52:37',
#   'customer': 'CUST-29',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-04 17:51:16',
#   'customer': 'CUST-75',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-04 17:18:13',
#   'customer': 'CUST-75',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-04 17:37:47',
#   'customer': 'CUST-75',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-04 17:50:55',
#   'customer': 'CUST-75',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-04 17:41:07',
#   'customer': 'CUST-75',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-12 11:19:25',
#   'customer': 'CUST-63',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-12 11:40:14',
#   'customer': 'CUST-63',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-12 11:33:49',
#   'customer': 'CUST-63',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-27 21:42:03',
#   'customer': 'CUST-59',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-27 21:33:03',
#   'customer': 'CUST-59',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-27 21:24:39',
#   'customer': 'CUST-59',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-27 21:21:33',
#   'customer': 'CUST-59',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-27 21:31:54',
#   'customer': 'CUST-59',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-27 21:03:17',
#   'customer': 'CUST-59',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-28 13:03:18',
#   'customer': 'CUST-68',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-28 13:13:56',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-28 13:18:07',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-28 13:47:15',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-28 13:30:47',
#   'customer': 'CUST-68',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-28 13:28:21',
#   'customer': 'CUST-68',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-28 13:51:33',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-21 12:26:37',
#   'customer': 'CUST-46',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-21 12:23:39',
#   'customer': 'CUST-46',
#   'location': 'Chips'},
#  {'timestamp': '2019-03-21 12:13:29',
#   'customer': 'CUST-46',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-21 12:54:42',
#   'customer': 'CUST-46',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-21 12:45:46',
#   'customer': 'CUST-46',
#   'location': 'Chips'},
#  {'timestamp': '2019-03-21 12:30:30',
#   'customer': 'CUST-46',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-21 12:27:34',
#   'customer': 'CUST-46',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-21 21:20:04',
#   'customer': 'CUST-51',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-21 21:31:28',
#   'customer': 'CUST-51',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-21 21:13:46',
#   'customer': 'CUST-51',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-21 21:58:56',
#   'customer': 'CUST-51',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-09 09:41:52',
#   'customer': 'CUST-4',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-09 09:03:53',
#   'customer': 'CUST-4',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-09 09:27:24',
#   'customer': 'CUST-4',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-09 09:04:43',
#   'customer': 'CUST-4',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-15 21:07:09',
#   'customer': 'CUST-68',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-15 21:23:37',
#   'customer': 'CUST-68',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-15 21:22:03',
#   'customer': 'CUST-68',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-15 21:44:48',
#   'customer': 'CUST-68',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-02 11:37:59',
#   'customer': 'CUST-94',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-02 11:56:25',
#   'customer': 'CUST-94',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-02 11:04:14',
#   'customer': 'CUST-94',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-02 11:23:48',
#   'customer': 'CUST-94',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-02 11:24:26',
#   'customer': 'CUST-94',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-15 17:47:18',
#   'customer': 'CUST-69',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-15 17:33:55',
#   'customer': 'CUST-69',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-15 17:56:28',
#   'customer': 'CUST-69',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-15 17:19:47',
#   'customer': 'CUST-69',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-05 15:09:04',
#   'customer': 'CUST-29',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-05 15:26:55',
#   'customer': 'CUST-29',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-05 15:37:16',
#   'customer': 'CUST-29',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-05 15:55:09',
#   'customer': 'CUST-29',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-01 10:41:53',
#   'customer': 'CUST-41',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-01 10:32:47',
#   'customer': 'CUST-41',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-01 10:29:19',
#   'customer': 'CUST-41',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-01 10:09:25',
#   'customer': 'CUST-41',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-01 10:26:26',
#   'customer': 'CUST-41',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-01 10:02:53',
#   'customer': 'CUST-41',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-01 10:24:45',
#   'customer': 'CUST-41',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-20 16:49:23',
#   'customer': 'CUST-24',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-20 16:23:43',
#   'customer': 'CUST-24',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-20 16:08:21',
#   'customer': 'CUST-24',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-20 16:56:50',
#   'customer': 'CUST-24',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-18 15:47:51',
#   'customer': 'CUST-90',
#   'location': 'Chips'},
#  {'timestamp': '2019-03-08 14:51:43',
#   'customer': 'CUST-9',
#   'location': 'Chips'},
#  {'timestamp': '2019-03-08 14:28:19',
#   'customer': 'CUST-9',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-23 15:06:27',
#   'customer': 'CUST-94',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-23 15:26:37',
#   'customer': 'CUST-94',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-23 15:12:39',
#   'customer': 'CUST-94',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-23 15:17:39',
#   'customer': 'CUST-94',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-23 15:38:24',
#   'customer': 'CUST-94',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-13 09:56:05',
#   'customer': 'CUST-31',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-22 18:10:27',
#   'customer': 'CUST-41',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-03 19:42:26',
#   'customer': 'CUST-7',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-03 19:44:12',
#   'customer': 'CUST-7',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-03 19:22:51',
#   'customer': 'CUST-7',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-03 19:14:55',
#   'customer': 'CUST-7',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-23 20:44:39',
#   'customer': 'CUST-78',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-23 20:22:13',
#   'customer': 'CUST-78',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-23 20:41:14',
#   'customer': 'CUST-78',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-23 20:21:11',
#   'customer': 'CUST-78',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-23 20:36:13',
#   'customer': 'CUST-78',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-23 20:02:16',
#   'customer': 'CUST-78',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-16 15:17:07',
#   'customer': 'CUST-27',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-16 15:11:06',
#   'customer': 'CUST-27',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-16 15:58:20',
#   'customer': 'CUST-27',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-16 15:42:17',
#   'customer': 'CUST-27',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-16 15:20:23',
#   'customer': 'CUST-27',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-13 18:09:15',
#   'customer': 'CUST-59',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-13 18:33:12',
#   'customer': 'CUST-59',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-13 18:15:50',
#   'customer': 'CUST-59',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-13 18:48:38',
#   'customer': 'CUST-59',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-08 15:59:42',
#   'customer': 'CUST-28',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-08 15:44:47',
#   'customer': 'CUST-28',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-08 15:53:27',
#   'customer': 'CUST-28',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-08 15:23:55',
#   'customer': 'CUST-28',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-08 15:21:48',
#   'customer': 'CUST-28',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-08 15:08:37',
#   'customer': 'CUST-28',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-22 19:49:56',
#   'customer': 'CUST-30',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-22 19:19:15',
#   'customer': 'CUST-30',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-22 19:36:05',
#   'customer': 'CUST-30',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-04 15:26:22',
#   'customer': 'CUST-31',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-04 15:38:06',
#   'customer': 'CUST-31',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-04 15:52:52',
#   'customer': 'CUST-31',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-08 08:46:28',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-08 08:04:44',
#   'customer': 'CUST-25',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-08 08:24:21',
#   'customer': 'CUST-25',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-08 08:17:27',
#   'customer': 'CUST-25',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-09 12:50:41',
#   'customer': 'CUST-59',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-23 13:21:52',
#   'customer': 'CUST-58',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-23 13:14:41',
#   'customer': 'CUST-58',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-23 13:52:51',
#   'customer': 'CUST-58',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-23 13:05:14',
#   'customer': 'CUST-58',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-23 13:42:52',
#   'customer': 'CUST-58',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-23 13:03:06',
#   'customer': 'CUST-58',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-28 18:46:52',
#   'customer': 'CUST-4',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-28 18:01:15',
#   'customer': 'CUST-4',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-28 18:19:56',
#   'customer': 'CUST-4',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-09 21:49:24',
#   'customer': 'CUST-19',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-09 21:42:34',
#   'customer': 'CUST-19',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-09 21:56:23',
#   'customer': 'CUST-19',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-09 21:09:40',
#   'customer': 'CUST-19',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-22 19:16:10',
#   'customer': 'CUST-68',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-22 19:31:45',
#   'customer': 'CUST-68',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-22 19:50:01',
#   'customer': 'CUST-68',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-22 19:21:38',
#   'customer': 'CUST-68',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-22 19:49:55',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-22 19:36:42',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-22 19:48:05',
#   'customer': 'CUST-68',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-03 14:49:34',
#   'customer': 'CUST-82',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-03 14:38:06',
#   'customer': 'CUST-82',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-03 14:18:48',
#   'customer': 'CUST-82',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-03 14:06:41',
#   'customer': 'CUST-82',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-18 14:39:26',
#   'customer': 'CUST-24',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-18 14:58:53',
#   'customer': 'CUST-24',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-22 17:49:35',
#   'customer': 'CUST-11',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-22 17:22:51',
#   'customer': 'CUST-11',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-22 17:51:52',
#   'customer': 'CUST-11',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-07 21:13:29',
#   'customer': 'CUST-48',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-15 21:22:57',
#   'customer': 'CUST-26',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-15 21:57:47',
#   'customer': 'CUST-26',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-15 21:47:03',
#   'customer': 'CUST-26',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-15 21:51:27',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-15 21:01:14',
#   'customer': 'CUST-26',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-15 21:14:05',
#   'customer': 'CUST-26',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-15 21:09:19',
#   'customer': 'CUST-26',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-24 16:38:41',
#   'customer': 'CUST-88',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-24 16:13:09',
#   'customer': 'CUST-88',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-24 16:57:12',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-24 16:55:02',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-24 16:59:40',
#   'customer': 'CUST-88',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-24 16:21:52',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-06 13:05:13',
#   'customer': 'CUST-3',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-06 13:48:07',
#   'customer': 'CUST-3',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-06 13:57:27',
#   'customer': 'CUST-3',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-06 13:31:52',
#   'customer': 'CUST-3',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-06 13:02:24',
#   'customer': 'CUST-3',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-06 13:03:48',
#   'customer': 'CUST-3',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-19 17:57:39',
#   'customer': 'CUST-69',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-08 19:15:42',
#   'customer': 'CUST-70',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-08 19:30:37',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-08 19:27:52',
#   'customer': 'CUST-70',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-08 19:10:44',
#   'customer': 'CUST-70',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-08 19:01:23',
#   'customer': 'CUST-70',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-06 20:59:09',
#   'customer': 'CUST-25',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-20 12:09:46',
#   'customer': 'CUST-4',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-20 12:55:27',
#   'customer': 'CUST-4',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-20 12:47:14',
#   'customer': 'CUST-4',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-20 12:48:44',
#   'customer': 'CUST-4',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-20 12:04:44',
#   'customer': 'CUST-4',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-20 12:12:09',
#   'customer': 'CUST-4',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-15 11:09:42',
#   'customer': 'CUST-98',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-15 11:49:14',
#   'customer': 'CUST-98',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-15 11:23:32',
#   'customer': 'CUST-98',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-15 11:24:40',
#   'customer': 'CUST-98',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-15 11:55:36',
#   'customer': 'CUST-98',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-03 12:44:25',
#   'customer': 'CUST-73',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-02 16:52:16',
#   'customer': 'CUST-67',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-02 16:30:40',
#   'customer': 'CUST-67',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-02 16:22:39',
#   'customer': 'CUST-67',
#   'location': 'Chips'},
#  {'timestamp': '2019-03-02 16:12:03',
#   'customer': 'CUST-67',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-02 16:07:16',
#   'customer': 'CUST-67',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-02 16:45:09',
#   'customer': 'CUST-67',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-02 16:35:07',
#   'customer': 'CUST-67',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-15 09:56:31',
#   'customer': 'CUST-41',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-15 09:55:48',
#   'customer': 'CUST-41',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-15 09:20:01',
#   'customer': 'CUST-41',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-15 09:58:47',
#   'customer': 'CUST-41',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-15 09:20:38',
#   'customer': 'CUST-41',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-11 09:22:19',
#   'customer': 'CUST-86',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-11 09:40:30',
#   'customer': 'CUST-86',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-11 09:11:51',
#   'customer': 'CUST-86',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-11 09:50:38',
#   'customer': 'CUST-86',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-11 09:13:04',
#   'customer': 'CUST-86',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-11 09:50:04',
#   'customer': 'CUST-86',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-11 09:03:42',
#   'customer': 'CUST-86',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-11 18:33:26',
#   'customer': 'CUST-100',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-13 10:43:48',
#   'customer': 'CUST-27',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-13 10:13:06',
#   'customer': 'CUST-27',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-13 10:23:09',
#   'customer': 'CUST-27',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-19 15:39:19',
#   'customer': 'CUST-28',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-19 15:44:27',
#   'customer': 'CUST-28',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-19 15:44:21',
#   'customer': 'CUST-28',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-19 15:07:56',
#   'customer': 'CUST-28',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-19 15:36:01',
#   'customer': 'CUST-28',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-19 15:01:10',
#   'customer': 'CUST-28',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-19 15:43:25',
#   'customer': 'CUST-28',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-04 15:18:05',
#   'customer': 'CUST-86',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-04 15:06:16',
#   'customer': 'CUST-86',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-15 21:28:54',
#   'customer': 'CUST-3',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-15 21:23:41',
#   'customer': 'CUST-3',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-15 17:56:15',
#   'customer': 'CUST-94',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-15 17:08:20',
#   'customer': 'CUST-94',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-16 10:16:14',
#   'customer': 'CUST-59',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-16 10:50:15',
#   'customer': 'CUST-59',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-16 10:45:15',
#   'customer': 'CUST-59',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-16 10:08:16',
#   'customer': 'CUST-59',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-16 10:07:51',
#   'customer': 'CUST-59',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-16 18:26:26',
#   'customer': 'CUST-21',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-16 18:31:32',
#   'customer': 'CUST-21',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-16 18:22:39',
#   'customer': 'CUST-21',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-16 18:44:34',
#   'customer': 'CUST-21',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-21 17:27:54',
#   'customer': 'CUST-99',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-21 17:48:33',
#   'customer': 'CUST-99',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-21 17:09:34',
#   'customer': 'CUST-99',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-21 17:50:42',
#   'customer': 'CUST-99',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-21 17:05:46',
#   'customer': 'CUST-99',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-21 17:06:14',
#   'customer': 'CUST-99',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-23 21:04:05',
#   'customer': 'CUST-54',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-23 21:15:30',
#   'customer': 'CUST-54',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-23 21:44:52',
#   'customer': 'CUST-54',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-23 21:09:01',
#   'customer': 'CUST-54',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-23 21:36:13',
#   'customer': 'CUST-54',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-23 21:14:41',
#   'customer': 'CUST-54',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-23 21:16:33',
#   'customer': 'CUST-54',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-15 10:31:54',
#   'customer': 'CUST-77',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-15 10:59:03',
#   'customer': 'CUST-77',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-15 10:06:14',
#   'customer': 'CUST-77',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-15 10:33:27',
#   'customer': 'CUST-77',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-15 10:45:39',
#   'customer': 'CUST-77',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-27 21:43:31',
#   'customer': 'CUST-88',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-27 15:19:39',
#   'customer': 'CUST-98',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-27 15:44:58',
#   'customer': 'CUST-98',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-27 15:55:51',
#   'customer': 'CUST-98',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-08 13:07:13',
#   'customer': 'CUST-67',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-08 13:40:24',
#   'customer': 'CUST-67',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-08 13:35:10',
#   'customer': 'CUST-67',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-08 13:20:03',
#   'customer': 'CUST-67',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-08 13:36:24',
#   'customer': 'CUST-67',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-08 13:07:20',
#   'customer': 'CUST-67',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-03 17:10:56',
#   'customer': 'CUST-69',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-15 12:38:21',
#   'customer': 'CUST-54',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-15 12:40:30',
#   'customer': 'CUST-54',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-15 11:26:56',
#   'customer': 'CUST-96',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-15 11:43:42',
#   'customer': 'CUST-96',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-15 11:19:51',
#   'customer': 'CUST-96',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-20 09:11:24',
#   'customer': 'CUST-49',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-20 09:38:23',
#   'customer': 'CUST-49',
#   'location': 'Chips'},
#  {'timestamp': '2019-03-20 09:15:15',
#   'customer': 'CUST-49',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-27 20:45:07',
#   'customer': 'CUST-55',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-27 20:54:04',
#   'customer': 'CUST-55',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-10 21:25:10',
#   'customer': 'CUST-26',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-10 21:39:01',
#   'customer': 'CUST-26',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-10 21:27:29',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-10 21:54:33',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-10 21:03:52',
#   'customer': 'CUST-26',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-10 21:40:26',
#   'customer': 'CUST-26',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-16 08:22:07',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-24 13:06:44',
#   'customer': 'CUST-27',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-24 13:40:13',
#   'customer': 'CUST-27',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-06 12:22:57',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-06 12:12:20',
#   'customer': 'CUST-90',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-06 12:28:20',
#   'customer': 'CUST-90',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-06 12:53:33',
#   'customer': 'CUST-90',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-09 15:54:40',
#   'customer': 'CUST-31',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-09 15:21:56',
#   'customer': 'CUST-31',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-09 15:14:06',
#   'customer': 'CUST-31',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-26 13:29:45',
#   'customer': 'CUST-93',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-26 13:15:24',
#   'customer': 'CUST-93',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-26 13:47:30',
#   'customer': 'CUST-93',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-26 13:59:29',
#   'customer': 'CUST-93',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-26 13:47:29',
#   'customer': 'CUST-93',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-26 13:54:28',
#   'customer': 'CUST-93',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-26 13:38:30',
#   'customer': 'CUST-93',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-15 16:08:55',
#   'customer': 'CUST-54',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-15 16:34:06',
#   'customer': 'CUST-54',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-15 16:56:28',
#   'customer': 'CUST-54',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-15 16:09:09',
#   'customer': 'CUST-54',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-18 14:48:27',
#   'customer': 'CUST-30',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-18 14:45:48',
#   'customer': 'CUST-30',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-18 14:38:03',
#   'customer': 'CUST-30',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-18 14:32:49',
#   'customer': 'CUST-30',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-18 14:08:11',
#   'customer': 'CUST-30',
#   'location': 'Chips'},
#  {'timestamp': '2019-03-15 12:53:16',
#   'customer': 'CUST-72',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-17 18:54:14',
#   'customer': 'CUST-6',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-17 18:03:08',
#   'customer': 'CUST-6',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-17 18:08:09',
#   'customer': 'CUST-6',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-17 18:50:57',
#   'customer': 'CUST-6',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-17 18:57:47',
#   'customer': 'CUST-6',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-24 18:46:10',
#   'customer': 'CUST-28',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-24 18:42:40',
#   'customer': 'CUST-28',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-24 18:23:39',
#   'customer': 'CUST-28',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-24 18:17:33',
#   'customer': 'CUST-28',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-24 18:51:36',
#   'customer': 'CUST-28',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-24 18:01:10',
#   'customer': 'CUST-28',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-28 11:12:20',
#   'customer': 'CUST-37',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-28 11:10:31',
#   'customer': 'CUST-37',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-28 11:08:26',
#   'customer': 'CUST-37',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-28 11:54:28',
#   'customer': 'CUST-37',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-28 11:37:25',
#   'customer': 'CUST-37',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-28 11:51:57',
#   'customer': 'CUST-37',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-28 11:59:43',
#   'customer': 'CUST-37',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-19 11:24:22',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-19 11:27:30',
#   'customer': 'CUST-70',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-19 11:21:17',
#   'customer': 'CUST-70',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-19 11:22:03',
#   'customer': 'CUST-70',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-19 11:04:23',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-19 11:02:59',
#   'customer': 'CUST-70',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-19 11:03:24',
#   'customer': 'CUST-70',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-18 10:28:02',
#   'customer': 'CUST-25',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-18 10:08:19',
#   'customer': 'CUST-25',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-06 17:58:34',
#   'customer': 'CUST-70',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-06 17:35:05',
#   'customer': 'CUST-70',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-06 17:48:59',
#   'customer': 'CUST-70',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-06 17:03:36',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-06 17:13:20',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-06 17:35:05',
#   'customer': 'CUST-70',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-11 18:28:54',
#   'customer': 'CUST-79',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-11 18:38:24',
#   'customer': 'CUST-79',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-11 18:56:27',
#   'customer': 'CUST-79',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-11 18:37:36',
#   'customer': 'CUST-79',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-11 18:45:12',
#   'customer': 'CUST-79',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-11 18:19:31',
#   'customer': 'CUST-79',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-16 19:01:10',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-16 19:07:58',
#   'customer': 'CUST-68',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-16 19:44:40',
#   'customer': 'CUST-68',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-16 19:39:34',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-16 19:28:48',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-24 08:16:28',
#   'customer': 'CUST-32',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-24 08:47:09',
#   'customer': 'CUST-32',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-24 08:38:46',
#   'customer': 'CUST-32',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-14 14:54:30',
#   'customer': 'CUST-15',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-14 14:05:18',
#   'customer': 'CUST-15',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-14 14:29:26',
#   'customer': 'CUST-15',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-03 08:13:37',
#   'customer': 'CUST-12',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-03 08:14:31',
#   'customer': 'CUST-12',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-03 08:56:54',
#   'customer': 'CUST-12',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-03 08:23:29',
#   'customer': 'CUST-12',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-03 08:29:12',
#   'customer': 'CUST-12',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-21 13:58:38',
#   'customer': 'CUST-66',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-21 13:35:18',
#   'customer': 'CUST-66',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-21 13:18:37',
#   'customer': 'CUST-66',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-21 13:29:58',
#   'customer': 'CUST-66',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-21 13:02:23',
#   'customer': 'CUST-66',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-01 10:17:25',
#   'customer': 'CUST-91',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-01 10:45:04',
#   'customer': 'CUST-91',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-01 10:39:28',
#   'customer': 'CUST-91',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-13 10:20:20',
#   'customer': 'CUST-60',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-05 20:36:05',
#   'customer': 'CUST-29',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-05 20:50:51',
#   'customer': 'CUST-29',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-05 20:04:29',
#   'customer': 'CUST-29',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-05 20:49:55',
#   'customer': 'CUST-29',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-05 20:18:11',
#   'customer': 'CUST-29',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-05 20:41:48',
#   'customer': 'CUST-29',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-21 13:59:29',
#   'customer': 'CUST-88',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-21 13:50:42',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-21 13:23:32',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-21 13:09:12',
#   'customer': 'CUST-88',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-21 13:28:30',
#   'customer': 'CUST-88',
#   'location': 'Chips'},
#  {'timestamp': '2019-03-21 13:10:47',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-08 18:42:16',
#   'customer': 'CUST-28',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-08 18:04:34',
#   'customer': 'CUST-28',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-07 08:33:26',
#   'customer': 'CUST-100',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-07 08:42:14',
#   'customer': 'CUST-100',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-07 08:37:29',
#   'customer': 'CUST-100',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-07 08:36:01',
#   'customer': 'CUST-100',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-07 08:19:12',
#   'customer': 'CUST-100',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-25 13:36:31',
#   'customer': 'CUST-24',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-25 13:44:25',
#   'customer': 'CUST-24',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-25 13:04:46',
#   'customer': 'CUST-24',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-25 13:32:27',
#   'customer': 'CUST-24',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-25 13:59:42',
#   'customer': 'CUST-24',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-10 20:31:54',
#   'customer': 'CUST-38',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-10 20:44:01',
#   'customer': 'CUST-38',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-10 20:25:49',
#   'customer': 'CUST-38',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-10 20:40:09',
#   'customer': 'CUST-38',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-10 20:29:24',
#   'customer': 'CUST-38',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-10 14:56:29',
#   'customer': 'CUST-26',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-10 14:18:49',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-17 16:24:26',
#   'customer': 'CUST-28',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-17 16:01:02',
#   'customer': 'CUST-28',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-17 16:16:23',
#   'customer': 'CUST-28',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-17 16:25:15',
#   'customer': 'CUST-28',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-15 17:20:13',
#   'customer': 'CUST-86',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-15 17:39:10',
#   'customer': 'CUST-86',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-15 17:24:47',
#   'customer': 'CUST-86',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-15 17:04:07',
#   'customer': 'CUST-86',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-15 17:48:35',
#   'customer': 'CUST-86',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-25 19:40:59',
#   'customer': 'CUST-76',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-25 19:47:12',
#   'customer': 'CUST-76',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-25 19:21:04',
#   'customer': 'CUST-76',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-25 19:51:04',
#   'customer': 'CUST-76',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-25 19:18:36',
#   'customer': 'CUST-76',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-25 19:37:08',
#   'customer': 'CUST-76',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-13 17:17:23',
#   'customer': 'CUST-52',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-13 17:56:14',
#   'customer': 'CUST-52',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-13 17:50:37',
#   'customer': 'CUST-52',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-13 17:42:24',
#   'customer': 'CUST-52',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-13 17:23:11',
#   'customer': 'CUST-52',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-09 09:18:13',
#   'customer': 'CUST-46',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-09 09:05:03',
#   'customer': 'CUST-46',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-09 09:53:39',
#   'customer': 'CUST-46',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-09 09:06:58',
#   'customer': 'CUST-46',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-21 14:12:44',
#   'customer': 'CUST-67',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-21 14:56:21',
#   'customer': 'CUST-67',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-21 14:19:12',
#   'customer': 'CUST-67',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-28 16:42:46',
#   'customer': 'CUST-55',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-28 16:08:27',
#   'customer': 'CUST-55',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-28 16:50:43',
#   'customer': 'CUST-55',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-28 16:24:45',
#   'customer': 'CUST-55',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-28 16:05:24',
#   'customer': 'CUST-55',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-28 16:32:05',
#   'customer': 'CUST-55',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-04 19:23:46',
#   'customer': 'CUST-4',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-04 19:40:19',
#   'customer': 'CUST-4',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-04 19:02:47',
#   'customer': 'CUST-4',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-04 19:49:25',
#   'customer': 'CUST-4',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-04 19:01:15',
#   'customer': 'CUST-4',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-04 19:03:14',
#   'customer': 'CUST-4',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-10 16:05:40',
#   'customer': 'CUST-62',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-10 16:02:33',
#   'customer': 'CUST-62',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-07 13:32:42',
#   'customer': 'CUST-24',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-07 13:28:33',
#   'customer': 'CUST-24',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-07 13:21:54',
#   'customer': 'CUST-24',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-07 13:47:52',
#   'customer': 'CUST-24',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-07 13:32:37',
#   'customer': 'CUST-24',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-19 12:28:45',
#   'customer': 'CUST-60',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-19 12:48:57',
#   'customer': 'CUST-60',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-19 12:23:28',
#   'customer': 'CUST-60',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-19 12:30:17',
#   'customer': 'CUST-60',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-19 12:23:02',
#   'customer': 'CUST-60',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-19 12:10:03',
#   'customer': 'CUST-60',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-19 12:25:07',
#   'customer': 'CUST-60',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-24 08:39:20',
#   'customer': 'CUST-15',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-24 08:48:06',
#   'customer': 'CUST-15',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-17 20:13:24',
#   'customer': 'CUST-26',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-17 20:06:21',
#   'customer': 'CUST-26',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-17 20:28:06',
#   'customer': 'CUST-26',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-17 20:45:31',
#   'customer': 'CUST-26',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-17 20:04:05',
#   'customer': 'CUST-26',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-17 20:08:47',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-17 20:29:19',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-13 14:13:01',
#   'customer': 'CUST-37',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-13 14:55:01',
#   'customer': 'CUST-37',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-13 14:13:08',
#   'customer': 'CUST-37',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-13 14:42:04',
#   'customer': 'CUST-37',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-13 14:07:25',
#   'customer': 'CUST-37',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-13 14:26:54',
#   'customer': 'CUST-37',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-06 16:27:37',
#   'customer': 'CUST-51',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-20 15:25:26',
#   'customer': 'CUST-30',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-23 12:45:12',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-26 08:19:41',
#   'customer': 'CUST-37',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-26 08:13:34',
#   'customer': 'CUST-37',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-06 13:55:15',
#   'customer': 'CUST-26',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-06 13:22:40',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-06 13:26:56',
#   'customer': 'CUST-26',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-06 13:25:27',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-06 13:07:56',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-06 13:38:52',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-22 08:25:13',
#   'customer': 'CUST-43',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-22 08:07:04',
#   'customer': 'CUST-43',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-22 08:45:05',
#   'customer': 'CUST-43',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-22 08:12:12',
#   'customer': 'CUST-43',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-22 08:05:28',
#   'customer': 'CUST-43',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-22 08:20:09',
#   'customer': 'CUST-43',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-14 20:12:55',
#   'customer': 'CUST-55',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-19 12:47:19',
#   'customer': 'CUST-94',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-19 12:43:31',
#   'customer': 'CUST-94',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-19 12:25:27',
#   'customer': 'CUST-94',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-19 12:19:55',
#   'customer': 'CUST-94',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-19 12:35:48',
#   'customer': 'CUST-94',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-19 12:16:21',
#   'customer': 'CUST-94',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-18 21:55:57',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-18 21:08:38',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-18 21:37:14',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-18 21:44:19',
#   'customer': 'CUST-88',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-18 21:06:11',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-18 21:29:46',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-22 15:42:37',
#   'customer': 'CUST-49',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-22 15:07:32',
#   'customer': 'CUST-49',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-22 15:46:08',
#   'customer': 'CUST-49',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-22 15:08:11',
#   'customer': 'CUST-49',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-28 10:50:22',
#   'customer': 'CUST-66',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-28 10:01:42',
#   'customer': 'CUST-66',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-28 10:05:21',
#   'customer': 'CUST-66',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-28 10:58:51',
#   'customer': 'CUST-66',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-28 10:59:17',
#   'customer': 'CUST-66',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-28 10:33:28',
#   'customer': 'CUST-66',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-28 10:04:04',
#   'customer': 'CUST-66',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-09 18:52:55',
#   'customer': 'CUST-13',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-09 18:53:31',
#   'customer': 'CUST-13',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-09 18:55:20',
#   'customer': 'CUST-13',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-09 18:10:19',
#   'customer': 'CUST-13',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-09 18:33:20',
#   'customer': 'CUST-13',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-09 18:15:47',
#   'customer': 'CUST-13',
#   'location': 'Chips'},
#  {'timestamp': '2019-05-09 08:52:03',
#   'customer': 'CUST-43',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-09 08:05:08',
#   'customer': 'CUST-43',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-09 08:23:23',
#   'customer': 'CUST-43',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-09 08:19:29',
# ...
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-25 13:23:33',
#   'customer': 'CUST-89',
#   'location': 'Freezer'},
#  {'timestamp': '2019-06-25 13:59:05',
#   'customer': 'CUST-89',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-25 13:10:57',
#   'customer': 'CUST-89',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-18 21:33:50',
#   'customer': 'CUST-30',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-18 21:33:57',
#   'customer': 'CUST-30',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-18 21:05:25',
#   'customer': 'CUST-30',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-18 21:39:42',
#   'customer': 'CUST-30',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-18 21:55:01',
#   'customer': 'CUST-30',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-26 11:31:29',
#   'customer': 'CUST-28',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-26 11:31:35',
#   'customer': 'CUST-28',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-26 11:59:16',
#   'customer': 'CUST-28',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-26 11:31:59',
#   'customer': 'CUST-28',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-26 11:24:54',
#   'customer': 'CUST-28',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-27 17:53:10',
#   'customer': 'CUST-88',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-27 17:27:37',
#   'customer': 'CUST-88',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-27 17:03:10',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-27 17:51:36',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-27 17:27:31',
#   'customer': 'CUST-88',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-27 17:55:35',
#   'customer': 'CUST-88',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-18 10:25:32',
#   'customer': 'CUST-17',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-18 10:14:18',
#   'customer': 'CUST-17',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-06 18:25:18',
#   'customer': 'CUST-37',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-06 18:13:36',
#   'customer': 'CUST-37',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-06 18:49:11',
#   'customer': 'CUST-37',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-06 18:58:02',
#   'customer': 'CUST-37',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-06 18:21:32',
#   'customer': 'CUST-37',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-06 18:23:11',
#   'customer': 'CUST-37',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-19 08:40:02',
#   'customer': 'CUST-41',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-19 08:26:21',
#   'customer': 'CUST-41',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-19 08:47:55',
#   'customer': 'CUST-41',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-19 08:10:08',
#   'customer': 'CUST-41',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-19 08:54:37',
#   'customer': 'CUST-41',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-23 18:13:17',
#   'customer': 'CUST-51',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-23 18:28:07',
#   'customer': 'CUST-51',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-23 18:52:28',
#   'customer': 'CUST-51',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-23 18:22:54',
#   'customer': 'CUST-51',
#   'location': 'Chips'},
#  {'timestamp': '2019-06-23 18:34:09',
#   'customer': 'CUST-51',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-23 18:26:52',
#   'customer': 'CUST-51',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-23 18:22:06',
#   'customer': 'CUST-51',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-09 19:51:52',
#   'customer': 'CUST-99',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-09 19:33:19',
#   'customer': 'CUST-99',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-09 19:36:44',
#   'customer': 'CUST-99',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-09 19:51:38',
#   'customer': 'CUST-99',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-19 16:31:42',
#   'customer': 'CUST-41',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-19 16:01:05',
#   'customer': 'CUST-41',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-19 16:22:04',
#   'customer': 'CUST-41',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-19 16:04:26',
#   'customer': 'CUST-41',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-19 16:42:39',
#   'customer': 'CUST-41',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-19 16:35:07',
#   'customer': 'CUST-41',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-24 11:06:19',
#   'customer': 'CUST-27',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-24 11:29:06',
#   'customer': 'CUST-27',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-24 11:38:21',
#   'customer': 'CUST-27',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-24 11:12:29',
#   'customer': 'CUST-27',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-24 11:10:57',
#   'customer': 'CUST-27',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-24 11:05:12',
#   'customer': 'CUST-27',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-24 11:53:11',
#   'customer': 'CUST-27',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-06 08:21:54',
#   'customer': 'CUST-86',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-06 08:21:10',
#   'customer': 'CUST-86',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-13 21:23:48',
#   'customer': 'CUST-6',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-13 21:55:10',
#   'customer': 'CUST-6',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-02 20:20:36',
#   'customer': 'CUST-69',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-02 20:01:26',
#   'customer': 'CUST-69',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-02 20:58:53',
#   'customer': 'CUST-69',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-19 14:52:04',
#   'customer': 'CUST-26',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-19 14:47:18',
#   'customer': 'CUST-26',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-19 14:03:40',
#   'customer': 'CUST-26',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-19 14:42:43',
#   'customer': 'CUST-26',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-22 08:04:03',
#   'customer': 'CUST-99',
#   'location': 'Cookies'},
#  {'timestamp': '2019-04-22 08:55:38',
#   'customer': 'CUST-99',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-21 15:55:34',
#   'customer': 'CUST-68',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-21 15:44:08',
#   'customer': 'CUST-68',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-23 16:08:13',
#   'customer': 'CUST-91',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-23 16:24:12',
#   'customer': 'CUST-91',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-23 16:51:24',
#   'customer': 'CUST-91',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-23 16:58:56',
#   'customer': 'CUST-91',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-06 08:59:37',
#   'customer': 'CUST-67',
#   'location': 'Produce'},
#  {'timestamp': '2019-06-06 08:05:09',
#   'customer': 'CUST-67',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-17 15:23:47',
#   'customer': 'CUST-94',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-17 15:03:10',
#   'customer': 'CUST-94',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-27 10:16:55',
#   'customer': 'CUST-6',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-27 10:35:38',
#   'customer': 'CUST-6',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-27 10:05:58',
#   'customer': 'CUST-6',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-06 13:15:38',
#   'customer': 'CUST-59',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-06 13:54:33',
#   'customer': 'CUST-59',
#   'location': 'Cookies'},
#  {'timestamp': '2019-05-06 13:15:22',
#   'customer': 'CUST-59',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-06 13:33:22',
#   'customer': 'CUST-59',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-18 12:51:46',
#   'customer': 'CUST-93',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-18 12:15:03',
#   'customer': 'CUST-93',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-18 12:32:05',
#   'customer': 'CUST-93',
#   'location': 'Cookies'},
#  {'timestamp': '2019-02-18 12:58:05',
#   'customer': 'CUST-93',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-18 12:33:32',
#   'customer': 'CUST-93',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-18 12:46:46',
#   'customer': 'CUST-93',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-18 12:47:51',
#   'customer': 'CUST-93',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-20 16:13:27',
#   'customer': 'CUST-7',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-08 19:21:17',
#   'customer': 'CUST-19',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-08 19:01:19',
#   'customer': 'CUST-19',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-08 19:46:37',
#   'customer': 'CUST-19',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-08 19:24:31',
#   'customer': 'CUST-19',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-08 19:53:28',
#   'customer': 'CUST-19',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-08 19:31:31',
#   'customer': 'CUST-19',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-14 20:15:59',
#   'customer': 'CUST-31',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-14 20:19:41',
#   'customer': 'CUST-31',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-14 20:43:09',
#   'customer': 'CUST-31',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-14 20:40:02',
#   'customer': 'CUST-31',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-28 14:18:31',
#   'customer': 'CUST-57',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-08 18:36:11',
#   'customer': 'CUST-31',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-08 18:17:15',
#   'customer': 'CUST-31',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-08 18:31:49',
#   'customer': 'CUST-31',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-08 18:52:58',
#   'customer': 'CUST-31',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-22 15:18:13',
#   'customer': 'CUST-62',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-22 15:21:50',
#   'customer': 'CUST-62',
#   'location': 'Dairy'},
#  {'timestamp': '2019-02-22 15:46:08',
#   'customer': 'CUST-62',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-22 15:26:54',
#   'customer': 'CUST-62',
#   'location': 'Chips'},
#  {'timestamp': '2019-02-22 15:38:13',
#   'customer': 'CUST-62',
#   'location': 'Cookies'},
#  {'timestamp': '2019-06-20 16:59:07',
#   'customer': 'CUST-24',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-20 16:40:11',
#   'customer': 'CUST-24',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-10 09:56:05',
#   'customer': 'CUST-17',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-11 18:09:43',
#   'customer': 'CUST-54',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-11 18:17:13',
#   'customer': 'CUST-54',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-11 18:21:34',
#   'customer': 'CUST-54',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-11 18:46:27',
#   'customer': 'CUST-54',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-11 18:53:07',
#   'customer': 'CUST-54',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-04 14:21:41',
#   'customer': 'CUST-31',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-04 14:42:29',
#   'customer': 'CUST-31',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-04 14:13:29',
#   'customer': 'CUST-31',
#   'location': 'Chips'},
#  {'timestamp': '2019-01-04 14:56:28',
#   'customer': 'CUST-31',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-04 14:50:27',
#   'customer': 'CUST-31',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-04 14:24:27',
#   'customer': 'CUST-31',
#   'location': 'Dairy'},
#  {'timestamp': '2019-06-23 17:09:23',
#   'customer': 'CUST-94',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-23 17:59:26',
#   'customer': 'CUST-94',
#   'location': 'Cereal'},
#  {'timestamp': '2019-06-23 17:26:08',
#   'customer': 'CUST-94',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-27 15:19:15',
#   'customer': 'CUST-14',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-27 15:53:26',
#   'customer': 'CUST-14',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-06 15:59:55',
#   'customer': 'CUST-94',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-15 19:41:41',
#   'customer': 'CUST-63',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-12 14:25:01',
#   'customer': 'CUST-57',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-12 14:25:55',
#   'customer': 'CUST-57',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-12 14:19:30',
#   'customer': 'CUST-57',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-12 14:44:03',
#   'customer': 'CUST-57',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-12 14:05:14',
#   'customer': 'CUST-57',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-12 14:06:13',
#   'customer': 'CUST-57',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-23 11:48:52',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-23 11:29:07',
#   'customer': 'CUST-70',
#   'location': 'Freezer'},
#  {'timestamp': '2019-01-23 11:35:10',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-02-02 16:36:03',
#   'customer': 'CUST-63',
#   'location': 'Freezer'},
#  {'timestamp': '2019-02-02 16:58:17',
#   'customer': 'CUST-63',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-05 21:39:52',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-05 21:06:52',
#   'customer': 'CUST-70',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-05 21:29:03',
#   'customer': 'CUST-70',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-05 21:12:11',
#   'customer': 'CUST-70',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-02 13:20:04',
#   'customer': 'CUST-48',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-02 13:04:51',
#   'customer': 'CUST-48',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-02 13:02:46',
#   'customer': 'CUST-48',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-02 13:29:40',
#   'customer': 'CUST-48',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-02 13:06:30',
#   'customer': 'CUST-48',
#   'location': 'Dairy'},
#  {'timestamp': '2019-04-02 13:24:31',
#   'customer': 'CUST-48',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-02 13:34:44',
#   'customer': 'CUST-48',
#   'location': 'Freezer'},
#  {'timestamp': '2019-05-20 12:45:15',
#   'customer': 'CUST-67',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-20 12:09:20',
#   'customer': 'CUST-67',
#   'location': 'Cereal'},
#  {'timestamp': '2019-05-20 12:13:02',
#   'customer': 'CUST-67',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-20 12:23:43',
#   'customer': 'CUST-67',
#   'location': 'Produce'},
#  {'timestamp': '2019-05-20 12:04:07',
#   'customer': 'CUST-67',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-24 16:18:55',
#   'customer': 'CUST-60',
#   'location': 'Produce'},
#  {'timestamp': '2019-01-24 16:03:09',
#   'customer': 'CUST-60',
#   'location': 'Cookies'},
#  {'timestamp': '2019-01-24 16:21:31',
#   'customer': 'CUST-60',
#   'location': 'Cereal'},
#  {'timestamp': '2019-01-24 16:44:08',
#   'customer': 'CUST-60',
#   'location': 'Dairy'},
#  {'timestamp': '2019-01-24 16:37:41',
#   'customer': 'CUST-60',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-24 17:30:07',
#   'customer': 'CUST-71',
#   'location': 'Cereal'},
#  {'timestamp': '2019-03-24 17:25:06',
#   'customer': 'CUST-71',
#   'location': 'Cookies'},
#  {'timestamp': '2019-03-24 17:46:01',
#   'customer': 'CUST-71',
#   'location': 'Freezer'},
#  {'timestamp': '2019-03-24 17:45:53',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-03-24 17:05:05',
#   'customer': 'CUST-71',
#   'location': 'Produce'},
#  {'timestamp': '2019-03-24 17:01:39',
#   'customer': 'CUST-71',
#   'location': 'Dairy'},
#  {'timestamp': '2019-05-16 09:28:08',
#   'customer': 'CUST-44',
#   'location': 'Cereal'},
#  {'timestamp': '2019-04-21 16:59:38',
#   'customer': 'CUST-96',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-21 16:19:37',
#   'customer': 'CUST-96',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-21 16:45:57',
#   'customer': 'CUST-96',
#   'location': 'Chips'},
#  {'timestamp': '2019-04-21 16:09:58',
#   'customer': 'CUST-96',
#   'location': 'Freezer'},
#  {'timestamp': '2019-04-21 16:46:54',
#   'customer': 'CUST-96',
#   'location': 'Produce'},
#  {'timestamp': '2019-04-21 16:35:10',
#   'customer': 'CUST-96',
#   'location': 'Produce'},
#  {'timestamp': '2019-02-15 17:26:52',
#   'customer': 'CUST-93',
#   'location': 'Produce'},
#  ...]
